# %%
from gensim.models import Word2Vec
import jieba
import emoji
import pandas as pd
import numpy as np

train_path = 'train_x.csv'
test_path = 'test_x.csv'
y_path = 'train_y.csv'
dict_txt_path = 'dict.txt.big'
x_type = {'id': int, 'comment':str}

# %%
jieba.load_userdict(dict_txt_path)

train_df = pd.read_csv(train_path, sep=',', dtype=x_type, index_col=0)
test_df = pd.read_csv(test_path, sep=',', dtype=x_type, index_col=0)
sentence_df = pd.concat([train_df, test_df])
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.469 seconds.
# Prefix dict has been built succesfully.

# %%
sentence_df
# Out:
#                                                  comment
# id
# 0      B3 B5 餅皮做法在這裡～內餡就單純鮮奶油打發抹上去就好 太麻煩了偶爾打發時間就好😂 B6...
# 1                                              今天看到最美的畫面
# 2                                    B3 希望之後能在熱血團看你po道歉文
# 3      還沒看過液體衛生棉本人的女子在這🙋🏻😭😭😭 我去全聯找了好多次都缺貨啊 到底哪裡有！！！！！...
# 4                                               哈哈  你活該啊
# 5      B113 笑死，說來聽聽那間公司用你來當技術員 又或是國營企業靠年資先上位然後就眼紅高學歷學...
# 6                                                自殺月經文⋯⋯
# 7                                     看到樓上的留言覺得你可以裝傻問問看😂
# 8                                                     不揪
# 9      只有台南特別不一樣 南部騎山豬就算了 還分哪裡觀光客能吃的，在地人能吃的 希望你們不要出台南...
# 10     想辦法搞死👿 讓她名聲臭掉 然後👿名聲臭掉回頭找妳姐時 叫妳姐不要心軟 不過也要小心👿會不會...
# 11     B63 原來如此，以後開數萬間貓廟、貓堂來供奉牠們好了，如此的不可一世、萬人寵幸，當真為萬物...
# 12                                 你把錢省下來 拿去投資 早點買房子比較實際
# 13                                     好希望能夠在看到MOBB出新專輯😢
# 14                                          會自己上台表演順便當評審
# 15                         B26 那政府既然課我們稅 為什麼不把逃稅大戶抓一抓呢？？
# 16                                          妳有沒有去申請殘障手冊？
# 17                             B2397 這些大概20級也可以吧 應該有報就上了
# 18                                    想說怎麼有這麼可愛的小筆電還比手機小
# 19                                             喔喔學校有英語系喔
# 20              B0  你要好好珍惜你那位浪漫的男朋友 看看我家的這位 這回應我也是醉了😂😂😂
# 21                                                  這篇會爆
# 22                          很有道理 其實大家都知道 但能不能實際去做又是另一件事了
# 23                 哪天推行奴隸制的時候出來講大家都不尊重推行奴隸制的人，我會出來看的，看笑話
# 24     台灣不是國家  請看國際認證!!!  台灣=中華人民共和國的一省=中國的一省  證據如下： ...
# 25                                                穿塑膠袋也美
# 26                                              B107 真會掰
# 27     B506  匿名聞名的DCARD IP你都抓的到 那這邊的工程師都是廢物嗎？ 單純提問  然...
# 28     創作就創作 在那邊講的跟真的一樣 這裡告訴大家創作怎麼區分 匿名打好一篇短文 然後底下留言一...
# 29     B64 樓上是工館肥宅發言嗎？全校剩你不知道你們系是肥宅系？只有當工具人的命啊～死臭宅，我都...
# ...                                                  ...
# 19970                                          這首不是抄襲嗎⋯⋯
# 19971  B1 你知道請一個講師來演講多麽不容易嗎！ 就算你不想參加  也請尊重一下 我並不是在幫動物...
# 19972                               懶就是懶 裝可愛噁心死了 尤其是那個聲音
# 19973  我真的不懂這些罵別人的男性朋友們在想什麼，蠻為你們感到可悲的，不要交不到女朋友就在那邊該，你...
# 19974  等下就會有正義路人來說：「煩不煩？到底要幾篇？」 然後BLIND一開始裝理性 被打臉打到很痛...
# 19975     Fly的舞台超短可是我超喜歡的QQ 今年的合作舞台我覺得都蠻好看的 但太短了覺得看不夠😭😭😭
# 19976                           B47 應該花了不少錢吧 原本長得像路邊的國中生
# 19977                交換日記絕對要上鎖 話說我還玩過文具店電子雞 當時最夯的智慧裝置了😁😁
# 19978  不要在那邊一直大陸法系 別在那邊脫褲子放不出屁 來啊講啊，你又知道什麼是英美法系？ 德派跟日...
# 19979                                             有帶腦出門?
# 19980          我有個臭肥宅男友，我該注意什麼😭😭 所謂乳繩雙馬尾👇 某部動漫女主角，雖然我沒看😅
# 19981                    B37 天啊～是我留言欸～感覺光榮😂😂😂 長照林小姐 你說呢～
# 19982  看到中間就已經猜到結局了 而且鋪陳很冗長 有點虎頭蛇尾 一個結尾主角開外掛 咻咻咻殺完大家 ...
# 19983                              你還愣在那邊幹嘛??!! 還不快拍照!!!
# 19984  原來是個喜歡下棋的學生   我這邊有一整副棋，讓你擁有更多樣的選擇 看你是要約將帥，約士，約...
# 19985                                  B415 低能總比心思惡臭的人好啦
# 19986                     早就說了 甲甲都是一群噁心又喜歡一言堂的傢伙 嘔嘔嘔嘔嘔嘔嘔
# 19987                                             左邊是猿人嗎
# 19988                就算是上課也不應該穿拖鞋去上課吧？ 還什麼形式上而已？ 腦子壞掉了嗎？
# 19989  原po妳是不是沒朋友😂😂😂 還是你們系不讓你參加宿營啊 妳有沒有想過 如果人家有申請呢？ 我...
# 19990                            覺得蠻無聊的  簡單來看 不就是花錢然後包膜嗎
# 19991                                              屍體的味道
# 19992                        驚！女友在脖子「種草莓」　 17歲少年大腦中風身亡
# 19993  B109  完全同意這樓  歌曲好不好聽本來就很主觀， 我就覺得這次SIGNAL很好聽啊， ...
# 19994                    會計一堆自以為網紅的醜八怪，對就是妳別懷疑，在幕後搞背刺的那位
# 19995  B25人家有規定遵守很難嗎？ 跳舞一點也不妨礙風化 不曉得你的跳舞是什麼？ 另外那你可以去回...
# 19996  我是不知道有什麼理由可以停權我帳號拉⋯ 但我要在哪裡留言是我的事情吧？ 而且從頭到尾我都沒有...
# 19997  我看過一個媽媽，好吧我真的不認為她夠格稱為媽媽!  小孩目測大概3-4歲，媽媽也沒牽，就這樣...
# 19998  之前跟大陸打來的詐騙聊一下 隔天他打過來感謝我 說那通電話是審核他能不能錄取的最後關卡 之後...
# 19999  是蠻爛的沒錯 小學員一進去沒半個人帶到小隊 還有自己找 還有沒有買票的人也可以進來是～怎樣？...
#
# [140000 rows x 1 columns]

# %%
words = []
for sentence in sentence_df['comment']:
    words.append(list(jieba.cut(emoji.demojize(sentence), cut_all=False)))
words
# Out:
# [['B3',
#   ' ',
#   'B5',
#   ' ',
#   '餅皮',
#   '做法',
#   '在',
#   '這裡',
#   '～',
#   '內餡',
#   '就',
#   '單純',
#   '鮮奶油',
#   '打發',
#   '抹上去',
#   '就',
#   '好',
#   ' ',
#   '太',
#   '麻煩',
#   '了',
#   '偶爾',
#   '打發',
#   '時間',
#   '就',
#   '好',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':',
#   ' ',
#   'B6',
#   ' ',
#   '抹',
#   '茶',
#   ':',
#   'thumbs',
#   '_',
#   'up',
#   ':',
#   ':',
#   'thumbs',
#   '_',
#   'up',
#   ':',
#   ':',
#   'thumbs',
#   '_',
#   'up',
#   ':'],
#  ['今天', '看到', '最美', '的', '畫面'],
#  ['B3', ' ', '希望', '之後', '能', '在', '熱血', '團看', '你', 'po', '道歉', '文'],
#  ['還沒',
#   '看過',
#   '液體',
#   '衛生棉',
#   '本人',
#   '的',
#   '女子',
#   '在',
#   '這',
#   ':',
#   'person',
#   '_',
#   'raising',
#   '_',
#   'hand',
#   '_',
#   'light',
#   '_',
#   'skin',
#   '_',
#   'tone',
#   ':',
#   ':',
#   'loudly',
#   '_',
#   'crying',
#   '_',
#   'face',
#   ':',
#   ':',
#   'loudly',
#   '_',
#   'crying',
#   '_',
#   'face',
#   ':',
#   ':',
#   'loudly',
#   '_',
#   'crying',
#   '_',
#   'face',
#   ':',
#   ' ',
#   '我',
#   '去',
#   '全聯',
#   '找',
#   '了',
#   '好',
#   '多次',
#   '都',
#   '缺貨',
#   '啊',
#   ' ',
#   '到底',
#   '哪裡',
#   '有',
#   '！',
#   '！',
#   '！',
#   '！',
#   '！',
#   '！',
#   '！',
#   '！',
#   '！',
#   '等',
#   '得',
#   '月經',
#   '都',
#   '來',
#   '了',
#   ':',
#   'expressionless',
#   '_',
#   'face',
#   ':'],
#  ['哈哈', ' ', ' ', '你', '活該', '啊'],
#  ['B113',
#   ' ',
#   '笑',
#   '死',
#   '，',
#   '說來聽聽',
#   '那',
#   '間',
#   '公司',
#   '用',
#   '你',
#   '來當',
#   '技術員',
#   ' ',
#   '又',
#   '或是',
#   '國營企業',
#   '靠',
#   '年資',
#   '先',
#   '上位',
#   '然後',
#   '就',
#   '眼紅',
#   '高學歷',
#   '學生',
#   ' ',
#   '來電',
#   '電成',
#   '大生',
#   ' ',
#   '其實',
#   '大家',
#   '心裡',
#   '把',
#   '你',
#   '當個',
#   '屁',
#   '～',
#   '～',
#   '～',
#   '～'],
#  ['自殺', '月', '經文', '⋯', '⋯'],
#  ['看到',
#   '樓上',
#   '的',
#   '留言',
#   '覺得',
#   '你',
#   '可以',
#   '裝傻',
#   '問問看',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':'],
#  ['不', '揪'],
#  ['只有',
#   '台南',
#   '特別',
#   '不',
#   '一樣',
#   ' ',
#   '南部',
#   '騎',
#   '山豬',
#   '就算',
#   '了',
#   ' ',
#   '還分',
#   '哪裡',
#   '觀光客',
#   '能',
#   '吃',
#   '的',
#   '，',
#   '在',
#   '地人能',
#   '吃',
#   '的',
#   ' ',
#   '希望',
#   '你們',
#   '不要',
#   '出台',
#   '南',
#   '唷',
#   '唷',
#   '唷',
#   '！'],
#  ['想',
#   '辦法',
#   '搞',
#   '死',
#   ':',
#   'angry',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'horns',
#   ':',
#   ' ',
#   '讓',
#   '她',
#   '名聲',
#   '臭掉',
#   ' ',
#   '然後',
#   ':',
#   'angry',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'horns',
#   ':',
#   '名聲',
#   '臭掉',
#   '回頭',
#   '找',
#   '妳',
#   '姐時',
#   ' ',
#   '叫',
#   '妳',
#   '姐',
#   '不要',
#   '心軟',
#   ' ',
#   '不過',
#   '也',
#   '要',
#   '小心',
#   ':',
#   'angry',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'horns',
#   ':',
#   '會',
#   '不會',
#   '拿刀',
#   '砍',
#   '人',
#   '或是',
#   '潑',
#   '硫酸',
#   '就是',
#   '了'],
#  ['B63',
#   ' ',
#   '原來如此',
#   '，',
#   '以後',
#   '開',
#   '數萬',
#   '間',
#   '貓廟',
#   '、',
#   '貓堂',
#   '來',
#   '供奉',
#   '牠',
#   '們',
#   '好',
#   '了',
#   '，',
#   '如此',
#   '的',
#   '不可一世',
#   '、',
#   '萬人',
#   '寵幸',
#   '，',
#   '當真',
#   '為',
#   '萬物',
#   '之',
#   '首',
#   '，',
#   '如今',
#   '尚未',
#   '有',
#   '人體',
#   '祭',
#   '獻給',
#   '牠',
#   '們',
#   '還真',
#   '有點',
#   '說不過去',
#   '呢',
#   '。'],
#  ['你', '把', '錢', '省', '下來', ' ', '拿', '去', '投資', ' ', '早點', '買房子', '比較', '實際'],
#  ['好',
#   '希望',
#   '能夠',
#   '在',
#   '看到',
#   'MOBB',
#   '出',
#   '新專輯',
#   ':',
#   'crying',
#   '_',
#   'face',
#   ':'],
#  ['會', '自己', '上台', '表演', '順便', '當', '評審'],
#  ['B26',
#   ' ',
#   '那',
#   '政府',
#   '既然',
#   '課',
#   '我們',
#   '稅',
#   ' ',
#   '為',
#   '什麼',
#   '不',
#   '把',
#   '逃稅',
#   '大戶',
#   '抓',
#   '一',
#   '抓',
#   '呢',
#   '？',
#   '？'],
#  ['妳有', '沒有', '去', '申請', '殘障', '手冊', '？'],
#  ['B2397',
#   ' ',
#   '這些',
#   '大概',
#   '20',
#   '級',
#   '也',
#   '可以',
#   '吧',
#   ' ',
#   '應該',
#   '有報',
#   '就',
#   '上',
#   '了'],
#  ['想', '說', '怎麼', '有', '這麼', '可愛', '的', '小', '筆電', '還比', '手機', '小'],
#  ['喔', '喔', '學校', '有', '英語系', '喔'],
#  ['B0',
#   ' ',
#   ' ',
#   '你',
#   '要',
#   '好好',
#   '珍惜',
#   '你',
#   '那位',
#   '浪漫',
#   '的',
#   '男朋友',
#   ' ',
#   '看看',
#   '我家',
#   '的',
#   '這位',
#   ' ',
#   '這回',
#   '應',
#   '我',
#   '也',
#   '是',
#   '醉',
#   '了',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':',
#   ' '],
#  ['這篇會', '爆'],
#  ['很',
#   '有',
#   '道理',
#   ' ',
#   '其實',
#   '大家',
#   '都',
#   '知道',
#   ' ',
#   '但',
#   '能',
#   '不能',
#   '實際',
#   '去',
#   '做',
#   '又',
#   '是',
#   '另',
#   '一件',
#   '事',
#   '了'],
#  ['哪天',
#   '推行',
#   '奴隸制',
#   '的',
#   '時候',
#   '出',
#   '來講',
#   '大家',
#   '都',
#   '不',
#   '尊重',
#   '推行',
#   '奴隸制',
#   '的',
#   '人',
#   '，',
#   '我會',
#   '出來',
#   '看',
#   '的',
#   '，',
#   '看笑話'],
#  ['台灣',
#   '不是',
#   '國家',
#   ' ',
#   ' ',
#   '請',
#   '看',
#   '國際',
#   '認證',
#   '!',
#   '!',
#   '!',
#   ' ',
#   ' ',
#   '台灣',
#   '=',
#   '中華人民共和國',
#   '的',
#   '一省',
#   '=',
#   '中國',
#   '的',
#   '一省',
#   ' ',
#   ' ',
#   '證據',
#   '如下',
#   '：',
#   ' ',
#   '南海',
#   '仲裁',
#   '：',
#   ' ',
#   '不',
#   '認為',
#   '台灣',
#   '是',
#   '個',
#   '國家',
#   ' ',
#   '而是',
#   '“',
#   '中國',
#   '”',
#   '台灣',
#   '當局',
#   '。',
#   ' ',
#   '今年初',
#   '的',
#   '英國',
#   '連署',
#   '，',
#   ' ',
#   '英國',
#   '認為',
#   '：',
#   ' ',
#   '台灣',
#   '是',
#   '中華人民共和國',
#   '的',
#   '一個',
#   '省',
#   '，',
#   '而',
#   '不是',
#   '國家',
#   ' ',
#   '再次',
#   '認證',
#   '，',
#   '台灣',
#   '不是',
#   '國家',
#   ' ',
#   '國際',
#   '權威機構',
#   '再次',
#   '認證',
#   '：',
#   ' ',
#   'Taiwan',
#   ' ',
#   '(',
#   'province',
#   ' ',
#   'of',
#   ' ',
#   '”',
#   'China',
#   '“',
#   ')',
#   ' ',
#   '聯合國',
#   '認證',
#   '：',
#   ' ',
#   '台灣',
#   '只是',
#   '中華人民共和國',
#   '的',
#   '一個',
#   '省',
#   ' ',
#   '結論',
#   '：',
#   ' ',
#   '台灣',
#   '=',
#   '中華人民',
#   '共國',
#   '的',
#   '一個',
#   '省',
#   '=',
#   '中國',
#   '的',
#   '一個',
#   '省'],
#  ['穿', '塑膠袋', '也', '美'],
#  ['B107', ' ', '真會', '掰'],
#  ['B506',
#   ' ',
#   ' ',
#   '匿名',
#   '聞名',
#   '的',
#   'DCARD',
#   ' ',
#   'IP',
#   '你',
#   '都',
#   '抓',
#   '的',
#   '到',
#   ' ',
#   '那',
#   '這邊',
#   '的',
#   '工程師',
#   '都',
#   '是',
#   '廢物',
#   '嗎',
#   '？',
#   ' ',
#   '單純',
#   '提問',
#   ' ',
#   ' ',
#   '然後',
#   '我',
#   '覺得',
#   '都',
#   '自殺',
#   '不',
#   '尊重',
#   '自己',
#   '的',
#   '生命',
#   '了',
#   ' ',
#   '怎麼',
#   '還',
#   '一堆',
#   '低能兒',
#   '在',
#   '捧',
#   '他',
#   '懶',
#   '趴'],
#  ['創作',
#   '就',
#   '創作',
#   ' ',
#   '在',
#   '那邊',
#   '講的',
#   '跟',
#   '真的',
#   '一樣',
#   ' ',
#   '這裡',
#   '告訴',
#   '大家',
#   '創作',
#   '怎麼',
#   '區分',
#   ' ',
#   '匿名',
#   '打',
#   '好',
#   '一篇',
#   '短文',
#   ' ',
#   '然後',
#   '底下',
#   '留言',
#   '一概',
#   '不回',
#   ' ',
#   '讓',
#   '大家',
#   '互戰',
#   ' ',
#   '自己',
#   '旁邊',
#   '看戲',
#   ' ',
#   '說',
#   '中',
#   '了',
#   '吧',
#   '原',
#   'po'],
#  ['B64',
#   ' ',
#   '樓上',
#   '是',
#   '工館',
#   '肥宅',
#   '發言',
#   '嗎',
#   '？',
#   '全校',
#   '剩',
#   '你',
#   '不',
#   '知道',
#   '你們',
#   '系是',
#   '肥宅系',
#   '？',
#   '只有',
#   '當',
#   '工具',
#   '人',
#   '的',
#   '命',
#   '啊',
#   '～',
#   '死',
#   '臭宅',
#   '，',
#   '我',
#   '都',
#   '懷疑',
#   '工館',
#   '這麼',
#   '臭',
#   '你們',
#   '系',
#   '大概',
#   '占',
#   '百分之八十',
#   '七',
#   '趴',
#   '的',
#   '原因',
#   '吧'],
#  ['那', '你', '就', '快點', '分', ' ', '小', '事情', '大驚小怪', '的'],
#  ['還有', 'b54', ' ', '一樣', '醜'],
#  ['怎樣', '的', '人', '吸引', '到', '怎樣', '的', '人', ' ', '素質', '可見一斑'],
#  ['加油',
#   '各位',
#   '同志',
#   ' ',
#   '打退',
#   '迷妹',
#   ' ',
#   '叫',
#   '我們',
#   '不要',
#   '看',
#   ' ',
#   '還',
#   '不是',
#   '看',
#   '我們',
#   '的',
#   '留言',
#   '看',
#   '的',
#   '很爽',
#   ' ',
#   '處處',
#   '秀',
#   '下限',
#   ' ',
#   '越',
#   '講越',
#   '誇張',
#   ' ',
#   '迷妹',
#   '根本',
#   '無',
#   '自知',
#   '能力'],
#  ['我媽',
#   '昨天',
#   '也',
#   '拿給',
#   '我簽',
#   '欸',
#   ' ',
#   '我',
#   '直接',
#   '說',
#   '：',
#   ' ',
#   '媽',
#   ' ',
#   '這',
#   '公投',
#   '的',
#   '論點',
#   '太',
#   '薄弱',
#   '了',
#   ' ',
#   '我',
#   '無法',
#   '接受',
#   ' ',
#   ' ',
#   '結果',
#   '我媽',
#   '到',
#   '現在',
#   '還不',
#   '跟',
#   '我',
#   '講話',
#   '：',
#   '）'],
#  ['阿就瞎妹', '遇到', '垃圾', ' ', ' ', '不', '知道', '該', '說', '什麼'],
#  ['B91',
#   ' ',
#   ' ',
#   '摸摸',
#   '爛有紅',
#   '？',
#   '？',
#   '？',
#   '？',
#   '？',
#   '？',
#   '？',
#   '哈哈哈哈',
#   'ㄏ',
#   ' ',
#   '回歸連',
#   '候補',
#   '一位',
#   '都',
#   '迷',
#   'U',
#   'ㄋ',
#   ' ',
#   '講幹話',
#   '之前',
#   '先摸',
#   '一下',
#   '你',
#   'ㄉ',
#   '良心',
#   '豪',
#   'ㄇ',
#   ' ',
#   '不要',
#   '學',
#   '主子',
#   '拿',
#   '一位',
#   '還裝',
#   '無辜',
#   '⁽',
#   '⁽',
#   'ૢ',
#   '(',
#   '⁎',
#   '❝',
#   'ົ',
#   'ཽ',
#   'ω',
#   '❝',
#   'ົ',
#   'ཽ',
#   '⁎',
#   ')',
#   '✧'],
#  ['B5',
#   ' ',
#   '放',
#   '啊',
#   '大不了',
#   '帳號',
#   '被',
#   '封掉',
#   ' ',
#   ' ',
#   '沒關係',
#   '雞雞',
#   '比較',
#   '重要'],
#  ['機械', '的', '噁心', '嘴臉'],
#  ['梁山伯', '與', '祝英台', ' ', '王', '大陸', '與', '大', '平台'],
#  ['付錢', '啊'],
#  ['B194',
#   ' ',
#   '真的',
#   '，',
#   '你',
#   '也',
#   '別',
#   '高潮',
#   '了',
#   '快',
#   '去',
#   '運動',
#   '，',
#   '這樣',
#   '才',
#   '會',
#   '又',
#   '瘦',
#   '又',
#   '健康'],
#  ['你',
#   '把',
#   '現在',
#   '發文',
#   '的',
#   '時間',
#   ' ',
#   '拿',
#   '去',
#   '讀',
#   '轉學',
#   '考',
#   '不是',
#   '比較',
#   '好',
#   '嗎',
#   ' ',
#   ' ',
#   '你發',
#   '這篇',
#   '文能',
#   '表示',
#   '什麼',
#   '？',
#   ' ',
#   '你',
#   '還是',
#   '在',
#   '中國科大',
#   '啊'],
#  ['大家',
#   '最近',
#   '愛買',
#   '的',
#   'net',
#   '也',
#   '抄',
#   '很大',
#   '啊',
#   '！',
#   '跟',
#   'vans',
#   ' ',
#   'smith',
#   ' ',
#   'rosherun',
#   '一模一樣',
#   '的',
#   '都',
#   '有',
#   ' ',
#   '包款',
#   '也',
#   '抄襲',
#   'celine',
#   ' ',
#   'mk',
#   '等等'],
#  ['醒醒', '吧', ' ', '宗教', '這種', '事情', '不是', '給你', '這樣', '隨便', '開玩笑', '的'],
#  ['跟',
#   '她',
#   '說',
#   '你老',
#   '了',
#   '把',
#   '妳',
#   '送',
#   '安養院',
#   ' ',
#   '講這是',
#   '什麼',
#   '鬼話',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'rolling',
#   '_',
#   'eyes',
#   ':',
#   '️'],
#  ['我',
#   '也',
#   '是',
#   '~',
#   '交往',
#   '6',
#   '年',
#   '的',
#   '前男友',
#   '也',
#   '是',
#   '因為',
#   '覺得',
#   '都',
#   '交往',
#   '這麼久',
#   '了',
#   '，',
#   '再',
#   '忍忍',
#   '…',
#   '(',
#   '變得',
#   '沒什麼',
#   '交集',
#   '而且',
#   '對方',
#   '脾氣',
#   '越來越',
#   '大',
#   ')',
#   ' ',
#   '交往',
#   '到',
#   '10',
#   '年',
#   '，',
#   '完全',
#   '不提',
#   '結婚',
#   '的',
#   '事情',
#   '連我',
#   '自己',
#   '問都',
#   '乾脆',
#   '不讀',
#   '不回',
#   '(',
#   '當面',
#   '裝死',
#   ')',
#   '，',
#   '遠距',
#   '每天',
#   '一張',
#   '貼圖',
#   '結束',
#   '對話',
#   '、',
#   '來',
#   '我家',
#   '還對',
#   '我',
#   '發飆',
#   '害',
#   '我',
#   '哭',
#   '著',
#   '下樓',
#   '被',
#   '家人',
#   '看見',
#   '…',
#   '冷戰',
#   '後',
#   '提',
#   '分手',
#   '，',
#   '馬上',
#   '答應',
#   '我',
#   '哭',
#   '一晚',
#   '就',
#   '不',
#   '難過',
#   '了',
#   ':',
#   'expressionless',
#   '_',
#   'face',
#   ':',
#   ':',
#   'expressionless',
#   '_',
#   'face',
#   ':',
#   ':',
#   'expressionless',
#   '_',
#   'face',
#   ':',
#   ' ',
#   '後來',
#   '有',
#   '因為',
#   '看',
#   '在',
#   '時間',
#   '的',
#   '份',
#   '上',
#   '複合',
#   '，',
#   '可是',
#   '他',
#   '還是',
#   '一樣',
#   '…',
#   '而且',
#   '當',
#   '女生',
#   '死心',
#   '之後',
#   '要',
#   '回心轉意',
#   '很難',
#   '(',
#   '開始',
#   '討厭',
#   '他',
#   '的',
#   '味道',
#   '和觸',
#   '碰',
#   ')',
#   '。',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'medical',
#   '_',
#   'mask',
#   ':',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'medical',
#   '_',
#   'mask',
#   ':',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'medical',
#   '_',
#   'mask',
#   ':',
#   ' ',
#   ' ',
#   '而',
#   '現任',
#   '對',
#   '我',
#   '很',
#   '好',
#   '，',
#   '很快',
#   '的',
#   '就',
#   '論及',
#   '婚嫁',
#   '了',
#   ':',
#   'beaming',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'smiling',
#   '_',
#   'eyes',
#   ':',
#   ':',
#   'beaming',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'smiling',
#   '_',
#   'eyes',
#   ':',
#   ':',
#   'beaming',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'smiling',
#   '_',
#   'eyes',
#   ':'],
#  ['當大', '四下', '還', '一堆', '必修', '的', '時候', '整', '學期', '變', '高中生'],
#  ['你媽',
#   '真的',
#   '很棒',
#   '，',
#   '也',
#   '很',
#   '欣慰',
#   '她',
#   '有',
#   '你',
#   '這樣',
#   '懂事',
#   '的',
#   '女兒',
#   '。',
#   ' ',
#   '但是',
#   '那篇',
#   '是',
#   '一個',
#   '口出',
#   '惡言',
#   '罵人',
#   '妓女',
#   '，',
#   '跟',
#   '下面',
#   '的',
#   '人',
#   '做',
#   '回覆',
#   '也',
#   '是',
#   '帶刺',
#   '的',
#   '。',
#   ' ',
#   '你',
#   '這篇',
#   '應該',
#   '獨立',
#   '出來',
#   '，',
#   '不要',
#   '轉',
#   '她',
#   '的',
#   '出來',
#   '再',
#   '敘述',
#   '。'],
#  ['還有',
#   'IKON',
#   ' ',
#   'bobby',
#   '!',
#   '!',
#   ' ',
#   ' ',
#   '低到',
#   '你',
#   '不要',
#   '不要',
#   '的',
#   ':',
#   'heart',
#   '_',
#   'suit',
#   ':'],
#  ['就',
#   '我',
#   '所知',
#   ' ',
#   '文化',
#   '出去',
#   '比賽',
#   '的',
#   '系隊',
#   '拿',
#   '了',
#   '不少',
#   '好',
#   '成績',
#   ' ',
#   '因為',
#   '我們',
#   '沒',
#   '場地',
#   '所以',
#   '更',
#   '珍惜',
#   ' ',
#   ' ',
#   ' ',
#   '防守',
#   '相對',
#   '他校',
#   '而言',
#   '好',
#   '了',
#   '不少',
#   ' ',
#   '反觀',
#   '圖書館',
#   '的',
#   '聖',
#   '人們',
#   '怎會',
#   '到',
#   '文化',
#   '咧',
#   '我',
#   '也',
#   '是',
#   'ㄏ',
#   'ㄏ',
#   '的',
#   ' ',
#   '互相',
#   '尊重',
#   '很難',
#   '嗎',
#   ' ',
#   '學校',
#   '花錢',
#   '給',
#   '你們好',
#   '的',
#   '環境',
#   '讀書',
#   ' ',
#   '拿點',
#   '成績',
#   '出來',
#   '給人',
#   '看吧',
#   ' ',
#   '嘴成',
#   '這樣',
#   ' ',
#   '體育',
#   '不',
#   '被',
#   '尊重',
#   '也',
#   '只',
#   '在',
#   '台灣',
#   '而已',
#   ' ',
#   '早已',
#   '習慣',
#   '了',
#   ' ',
#   '場地',
#   '問題',
#   '也',
#   '不是',
#   '沒',
#   '反應',
#   '過',
#   '室內',
#   '留給',
#   '甲乙',
#   '組',
#   '不外借',
#   ' ',
#   '也',
#   '沒',
#   '啥',
#   '成績',
#   ' ',
#   '籃球',
#   '某',
#   '教練',
#   '針對',
#   '排球',
#   '搞',
#   '的',
#   '好像',
#   '籃球',
#   '很強',
#   '一樣',
#   ' ',
#   '籃球',
#   '出去',
#   '還',
#   '不是',
#   '輸',
#   '一堆',
#   '人',
#   ' ',
#   '大都',
#   '被',
#   '爽爽',
#   '刷',
#   ' ',
#   '別',
#   '在',
#   '戰',
#   '了',
#   '場地',
#   '問題',
#   '好幾十年',
#   '了',
#   ' ',
#   '回家',
#   '讀',
#   '你',
#   '的',
#   '書重',
#   '考上',
#   '台大',
#   '比較',
#   '實在',
#   '吧'],
#  ['裝', '這些', '容易', '噴掉', '的', '東西', '不如', '把', '錢', '省', '起來'],
#  ['一堆', '無辜', '的', '水瓶', '溺水', '了'],
#  ['內衣',
#   '哪裡',
#   '買',
#   '的',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':'],
#  ['草莓', ' ', '這樣', '就', '哭'],
#  ['「',
#   '我',
#   '的',
#   'sop',
#   '通常',
#   '是',
#   '中文',
#   '一次',
#   ' ',
#   '英文',
#   '再',
#   '一次',
#   ' ',
#   ' ',
#   '一',
#   '開始',
#   '就',
#   '認定',
#   '別人',
#   '聽不懂',
#   '中文',
#   '好像',
#   '有點',
#   '失禮',
#   '」',
#   ' ',
#   ' ',
#   '原',
#   'PO',
#   '很',
#   '讚',
#   '捏',
#   '，',
#   '我',
#   '也',
#   '想過',
#   '這個',
#   '問題',
#   '，',
#   '但是',
#   '要',
#   '我',
#   '直接',
#   '開',
#   '口說',
#   '中文',
#   '還是',
#   '不自在',
#   '。',
#   '下次',
#   '我會',
#   '加油',
#   '的',
#   '！'],
#  ['不是',
#   '沒有',
#   '選課',
#   '，',
#   '而是',
#   '助教',
#   '幫',
#   '你',
#   '選好',
#   '所以',
#   '不用',
#   '選課',
#   '，',
#   '看字',
#   'ok',
#   '?'],
#  ['我會', '更', '生氣'],
#  ['嗯',
#   '..',
#   '看',
#   '了',
#   '樓上',
#   ' ',
#   '不',
#   '知道',
#   '月亮',
#   '的',
#   '文',
#   '什麼',
#   '時候',
#   '開始',
#   '有',
#   '這麼',
#   '負面',
#   '的',
#   '留言',
#   '了',
#   ':',
#   'sad',
#   '_',
#   'but',
#   '_',
#   'relieved',
#   '_',
#   'face',
#   ':',
#   ' ',
#   '至少',
#   '我',
#   '看過',
#   '的',
#   '文章',
#   ' ',
#   '都',
#   '覺得',
#   '她',
#   '很',
#   '用心',
#   '在',
#   '分享',
#   ' ',
#   '而且',
#   '產量',
#   '超高',
#   '的',
#   '呀',
#   '～',
#   '收藏',
#   '好',
#   '多篇',
#   ' ',
#   '也',
#   '從來不',
#   '覺得',
#   '有曬照',
#   ' ',
#   '在',
#   '這裡',
#   '大家',
#   '都',
#   '是',
#   '一樣',
#   '的',
#   ' ',
#   '希望',
#   '每個',
#   '人',
#   '都',
#   '可以',
#   '公平',
#   '的',
#   '看待',
#   '彼此',
#   ' ',
#   '以',
#   '一個',
#   '分享',
#   '的',
#   '角度',
#   '來看',
#   '還',
#   '要求',
#   '別人',
#   '創新',
#   '我',
#   '是',
#   '覺得',
#   '有點',
#   '過了',
#   '啦',
#   ':',
#   'downcast',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'sweat',
#   ':',
#   ' ',
#   '青菜蘿蔔',
#   '各有所好',
#   ' ',
#   '給',
#   '建議',
#   '當然',
#   '是',
#   '可以',
#   '的',
#   ' ',
#   '不過',
#   '留言',
#   '的',
#   '口氣',
#   '可以',
#   '好',
#   '一點',
#   '嘛',
#   ' ',
#   '沒',
#   '必要',
#   '針對性',
#   '這麼',
#   '強啦',
#   '～',
#   '～',
#   ' ',
#   '畢竟',
#   '打',
#   '一篇',
#   '教學',
#   '文',
#   '也',
#   '是',
#   '很',
#   '辛苦',
#   '的',
#   '呀',
#   ':',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'smiling',
#   '_',
#   'eyes',
#   ':'],
#  ['B12', ' ', '五六', '餐', '哦', ' ', ' ', '吃屎', '吧', ' ', ' ', 'ㄏ', 'ㄏ'],
#  ['其實',
#   '不用',
#   '理他',
#   ' ',
#   '有',
#   '埋',
#   '就',
#   '好',
#   ' ',
#   ' ',
#   '他',
#   '的',
#   '最後',
#   '一句',
#   '讓',
#   '人',
#   '笑',
#   '死'],
#  ['B49',
#   '公審',
#   '的',
#   '不是',
#   '原原',
#   'po',
#   '嗎',
#   ' ',
#   '你',
#   '怎麼',
#   '自個',
#   '拉',
#   '椅子',
#   '去',
#   '坐',
#   '了',
#   '呢',
#   ' ',
#   '不',
#   '認識',
#   '事主',
#   '又',
#   '跟',
#   '發文',
#   '公審',
#   '目的',
#   '有',
#   '什麼',
#   '關係',
#   ' ',
#   '她',
#   '公眾',
#   '人物',
#   '所以',
#   '公審',
#   '理直氣壯',
#   '嗎',
#   ' ',
#   '換言之',
#   '不是',
#   '公眾',
#   '人物',
#   '就',
#   '不能',
#   '公審',
#   '囉',
#   '？',
#   ' ',
#   '公審',
#   '政治',
#   '人物',
#   '跟',
#   '明星',
#   '的',
#   '私生活',
#   '就',
#   '更',
#   '可笑',
#   '了',
#   ' ',
#   '你',
#   '怎麼',
#   '知道',
#   '我',
#   '對',
#   '這件',
#   '事',
#   '的',
#   '看法',
#   '？',
#   ' ',
#   '拜託',
#   '不要',
#   '妄加',
#   '揣測',
#   '哦',
#   '~'],
#  ['B15',
#   '感謝',
#   '妳',
#   '的',
#   '回覆',
#   '讓',
#   '我',
#   '能夠',
#   '跟',
#   '大家',
#   '說明',
#   '的',
#   '更',
#   '詳細',
#   '！',
#   ' ',
#   '其實',
#   '在',
#   '捐卵',
#   '這件',
#   '事情',
#   '的',
#   '面前',
#   '，',
#   '錢',
#   ' ',
#   '，',
#   '就',
#   '顯得',
#   '微不足道',
#   '了',
#   ' ',
#   '，',
#   '為',
#   '什麼',
#   '這麼',
#   '說',
#   '？',
#   ' ',
#   '捐卵',
#   '說',
#   '實在',
#   '有',
#   '他',
#   '一定',
#   '的',
#   '風險',
#   '，',
#   '尤其',
#   '手術',
#   '也',
#   '是',
#   '全身',
#   '麻醉',
#   '，',
#   '再來',
#   '就是',
#   '身體',
#   '的',
#   '營養',
#   '及',
#   '荷爾蒙',
#   '內分泌',
#   '會',
#   '在',
#   '你',
#   '捐卵',
#   '完',
#   '後',
#   '失調',
#   '，',
#   '所以',
#   '不是',
#   '什麼',
#   '都',
#   '能夠',
#   '用錢',
#   '衡量',
#   '的',
#   '，',
#   '如果',
#   '因為',
#   '只是',
#   '要錢',
#   '結果',
#   '身體',
#   '受傷',
#   '了',
#   '還是',
#   '發生',
#   '了',
#   '不可',
#   '挽回',
#   '的',
#   '遺憾',
#   '，',
#   '那',
#   '99000',
#   '夠你用',
#   '嗎',
#   '？',
#   ' ',
#   '所以',
#   '有要',
#   '捐卵',
#   '的',
#   '姐妹',
#   '們',
#   '一定',
#   '要',
#   '好好',
#   '衡量',
#   '自己',
#   '的',
#   '身體狀況',
#   '，',
#   '再',
#   '做',
#   '決定',
#   '！',
#   ' ',
#   'PS',
#   ':',
#   '原',
#   'po',
#   '捐',
#   '完卵',
#   '因為',
#   '內分泌',
#   '失調',
#   '感冒',
#   '了',
#   '好',
#   '幾天',
#   '，',
#   '情緒',
#   '波動',
#   '也',
#   '很大',
#   '（',
#   '一點',
#   '小事',
#   '就',
#   '跟',
#   '閃光',
#   '吵架',
#   '，',
#   '這段',
#   '時間',
#   '真是',
#   '辛苦',
#   '他',
#   '了',
#   '）',
#   ' ',
#   '因為',
#   '愛',
#   '，',
#   '所以',
#   '想',
#   '捐出',
#   '自己',
#   '身體',
#   '的',
#   '一部分',
#   '幫助',
#   '別人',
#   '，',
#   '這是',
#   '無價',
#   '的',
#   '！'],
#  ['不如',
#   '把',
#   '分享',
#   '器',
#   'DNS',
#   '改成',
#   'opendns',
#   ' ',
#   'family',
#   '鎖',
#   '色情網站',
#   ' ',
#   ' ',
#   '看',
#   '你',
#   '能',
#   '撐',
#   '幾天',
#   '喔'],
#  ['傻眼', ' ', '笑', '的', '出來', '的', '都', '有', '病', '吧'],
#  ['處女',
#   '女有',
#   '一個',
#   '壞毛病',
#   '，',
#   '會',
#   '不',
#   '小心',
#   '把',
#   '現在',
#   '擁有',
#   '的',
#   '當成',
#   '理所當然',
#   ' ',
#   ' ',
#   '但',
#   '不',
#   '代表',
#   '他',
#   '不',
#   '重視',
#   '，',
#   '他們',
#   '其實',
#   '很',
#   '細心',
#   '的',
#   '，',
#   '很多',
#   '你',
#   '沒',
#   '注意',
#   '到',
#   '的',
#   '小',
#   '地方',
#   '他們',
#   '都',
#   '會',
#   '記住',
#   ' ',
#   ' ',
#   '所以',
#   '不要',
#   '想太多',
#   '喔',
#   ' ',
#   ' ',
#   'bu',
#   '沒事',
#   '喜歡',
#   '研究',
#   '星座',
#   '的',
#   '人'],
#  ['管院',
#   '邊緣',
#   '人如',
#   '我',
#   '湊熱鬧',
#   '點',
#   '進來',
#   '看看',
#   ' ',
#   '樓上',
#   '電機',
#   '的',
#   '看來',
#   '是',
#   '覺得',
#   '匿名',
#   '就',
#   '開始',
#   '跩',
#   '了',
#   '呢',
#   ' ',
#   '看不起',
#   '這種',
#   '人',
#   ' ',
#   ' ',
#   '聰明',
#   '一點',
#   '會',
#   '考試',
#   '一點',
#   '真他媽',
#   '沒有',
#   '比較',
#   '厲害',
#   ' ',
#   'ㄏ'],
#  ['我',
#   '以前',
#   '也',
#   '問過',
#   '男同學',
#   ' ',
#   '「',
#   '尻',
#   '」',
#   '是',
#   '什麼',
#   ' ',
#   '他',
#   '有',
#   '回答',
#   '我',
#   '，',
#   '然後',
#   '兩個',
#   '人',
#   '一起',
#   '尷尬',
#   '=',
#   ' ',
#   '=',
#   '”'],
#  ['乾', '我', '屁', '4', ' ', '沒人', '想', '跟', '你', '玩', '啦', ' ', '邊緣', '人'],
#  ['自殺',
#   '可以',
#   '到',
#   '更好',
#   '的',
#   '地方',
#   '？',
#   ' ',
#   '那台灣',
#   '都',
#   '不用',
#   '健保',
#   '了',
#   '啊'],
#  ['B300', ' ', '幹嘛', ' ', '聊天', '啊'],
#  ['B6',
#   ' ',
#   '邊緣',
#   '人',
#   '又',
#   '怎樣',
#   '？',
#   '擔心',
#   '分組',
#   '就',
#   '不用',
#   '畢業',
#   '吧',
#   '！',
#   '我',
#   '邊緣',
#   '我',
#   '也',
#   '有',
#   '組分',
#   '了',
#   ' ',
#   '都',
#   '說',
#   '是',
#   '通識',
#   '課',
#   '理所當然',
#   '大多數',
#   '人',
#   '都',
#   '是',
#   '互不',
#   '認識',
#   '的',
#   ' ',
#   '懂',
#   '？',
#   '87'],
#  ['等等',
#   '這也',
#   '太快',
#   '了',
#   '吧',
#   'Ｏ',
#   '＿',
#   '＿',
#   '＿',
#   'Ｏ',
#   ' ',
#   '我',
#   '去',
#   '上個',
#   '廁所',
#   '回來',
#   '就',
#   '到達',
#   '了',
#   '哈哈哈',
#   ' ',
#   ' ',
#   '好',
#   '吧',
#   ' ',
#   '就',
#   '這張',
#   '而已',
#   ' ',
#   'XD',
#   '（',
#   '突然',
#   '發現',
#   '我',
#   '在',
#   '台灣',
#   '沒',
#   '拍',
#   '什麼',
#   '照',
#   '啊啊啊',
#   '而且',
#   '這',
#   '還是',
#   '肉',
#   '拍',
#   '的',
#   ' ',
#   ' '],
#  ['B86',
#   ' ',
#   '啊',
#   '我',
#   '發文',
#   '乾',
#   '你',
#   '屁事',
#   ' ',
#   '不爽',
#   '看',
#   '可以',
#   '滾',
#   ' ',
#   '我',
#   '重點',
#   '在',
#   '說',
#   '什麼',
#   '都',
#   '不',
#   '懂',
#   '可以',
#   '不要',
#   '一直',
#   '在',
#   '那邊',
#   '靠北',
#   '？',
#   ' ',
#   '有人',
#   '叫',
#   '你',
#   '找',
#   '？',
#   '可不可以',
#   '閉上',
#   '你',
#   '的',
#   '嘴'],
#  ['b52',
#   '你',
#   '學校',
#   '很',
#   '好',
#   '嗎',
#   '？',
#   '？',
#   '快',
#   '笑',
#   '屎',
#   '我',
#   '了',
#   ' ',
#   ' ',
#   '出來',
#   '做',
#   '直銷',
#   '嗎',
#   'ㄎ',
#   'ㄎ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '別講',
#   '不贏',
#   '就',
#   '戰',
#   '學校',
#   '啊',
#   '小孩子',
#   ' ',
#   ' ',
#   ' ',
#   '光頭',
#   '哥會森',
#   '氣氣',
#   '的',
#   ' ',
#   ' ',
#   '破',
#   '學校',
#   '就',
#   '乖',
#   '一點',
#   ' ',
#   '乖',
#   ' ',
#   'b41',
#   '.',
#   ' ',
#   '走',
#   '我們',
#   '騎白排',
#   '找',
#   '光頭',
#   '哥',
#   '一起',
#   '去',
#   '好',
#   '興奮',
#   '哦哦哦',
#   ':',
#   'heart',
#   '_',
#   'suit',
#   ':',
#   ':',
#   'heart',
#   '_',
#   'suit',
#   ':'],
#  ['有',
#   '看過',
#   '幾次',
#   '他',
#   '的',
#   '影片',
#   ' ',
#   '好笑',
#   '的',
#   '無聊',
#   '的',
#   '都',
#   '有',
#   ' ',
#   '但',
#   '就是',
#   '完全',
#   '沒',
#   '辦法',
#   '喜歡',
#   ' ',
#   '也',
#   '不會',
#   '想',
#   '訂閱',
#   ' ',
#   '不',
#   '知道',
#   '到底',
#   '是',
#   '哪裡',
#   '出',
#   '問題',
#   '哈哈'],
#  ['笑',
#   '死',
#   ' ',
#   '看',
#   '按',
#   '我',
#   '愛心',
#   '的',
#   '有',
#   '這麼',
#   '多人',
#   ' ',
#   '你',
#   '真以',
#   '為',
#   '你們',
#   '這些',
#   '魯蛇',
#   '男',
#   '很',
#   '好',
#   '？',
#   ' ',
#   '這樣',
#   '就',
#   '可以',
#   '知道',
#   '苦主',
#   '有夠',
#   '多',
#   '的',
#   ' ',
#   '我',
#   '才',
#   '不想',
#   '跟',
#   '你們',
#   '浪費時間',
#   '呢',
#   ' ',
#   'Bye',
#   '~'],
#  ['乖', '啦', '去', '緬懷', '版'],
#  ['好', '想', '揉', '爆', '妳', '的', '奶', '哦'],
#  ['B101',
#   ' ',
#   '不好意思',
#   '我',
#   '現在',
#   '有',
#   '女朋友',
#   '哦',
#   ' ',
#   '而且',
#   '女朋友',
#   '也',
#   '是',
#   '覺得',
#   '同性戀',
#   '症',
#   '患者',
#   '是',
#   '台灣',
#   '社會',
#   '上',
#   '的',
#   '一大',
#   '毒瘤',
#   ':',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'smiling',
#   '_',
#   'eyes',
#   ':',
#   ' ',
#   '哦',
#   '對',
#   '了',
#   ' ',
#   '我',
#   '看',
#   '不',
#   '瞭解',
#   '的',
#   '是',
#   '你',
#   '哦',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':',
#   ' ',
#   '可以',
#   '去',
#   '看',
#   '一下',
#   '這',
#   '篇文章',
#   ' ',
#   '醫生',
#   '說',
#   '的話',
#   '比',
#   '你',
#   '一個',
#   '不',
#   '知道',
#   '是',
#   '誰',
#   '的',
#   '人',
#   '可信度',
#   '還大',
#   '吧',
#   '^',
#   '__',
#   '^',
#   ' ',
#   '好',
#   '啦',
#   ' ',
#   '不嘴',
#   '了',
#   ' ',
#   '你們',
#   '就活',
#   '在',
#   '自己',
#   '的',
#   '小圈子',
#   '吧',
#   '努力',
#   '的',
#   '安慰',
#   '自己',
#   '其實',
#   '毒甲',
#   '是',
#   '可以',
#   '被',
#   '正視',
#   '的',
#   '吧',
#   ' ',
#   '最後',
#   '我',
#   '還是',
#   '希望',
#   '得病',
#   '的',
#   '人',
#   '可以',
#   '康復',
#   ' ',
#   '加油',
#   ':',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'halo',
#   ':'],
#  ['對不起', '，', '我', '膚淺', '一問', ' ', ' ', '家裡', '是否', '經濟', '不錯'],
#  ['天氣',
#   '這麼',
#   '熱',
#   ' ',
#   '男友',
#   '溫暖',
#   '的',
#   '像',
#   '火爐',
#   ' ',
#   '我',
#   '其實',
#   '也',
#   '不',
#   '太',
#   '願意',
#   '抱著',
#   '睡'],
#  ['推',
#   '心酸',
#   '史',
#   '、',
#   '遇到',
#   '太多衰',
#   '小事',
#   ' ',
#   '不要',
#   '每次',
#   '看到',
#   '我們',
#   '就',
#   '認為',
#   '我們',
#   '爽爽',
#   '賺錢',
#   ' ',
#   '完全',
#   '看不到',
#   '每個',
#   '工作者',
#   '背後',
#   '的',
#   '心酸',
#   ' ',
#   ' ',
#   '而',
#   '到底',
#   '誰',
#   '賺到',
#   '最',
#   '多',
#   '?',
#   '!',
#   '我',
#   '不願',
#   '多談',
#   ' ',
#   '大家',
#   '心知肚明',
#   ' ',
#   '那些',
#   '高層',
#   '就',
#   '只會',
#   '要求',
#   '東',
#   '要求',
#   '西',
#   ' ',
#   '而',
#   '不',
#   '考慮',
#   '這個',
#   '要求',
#   '的',
#   '合理性',
#   ' ',
#   '不是',
#   '動不動',
#   '就要',
#   '懲罰',
#   ' ',
#   ' ',
#   '你們',
#   '都',
#   '爽爽',
#   '坐在',
#   '辦公室',
#   '的',
#   '象牙塔',
#   '裡面',
#   ' ',
#   '底下',
#   '學生',
#   '出事',
#   '了',
#   '也',
#   '不',
#   '跳',
#   '出來',
#   '了解',
#   '狀況',
#   ' ',
#   '而',
#   '只是',
#   '出',
#   '事後',
#   ' ',
#   '一面',
#   '的',
#   '開',
#   '你們',
#   '的',
#   '秘密',
#   '會議',
#   ' ',
#   '然後',
#   '直接',
#   '對',
#   '底下',
#   '學生',
#   '做出',
#   '裁決',
#   ' ',
#   '完全',
#   '不',
#   '聽取',
#   '我們',
#   '這些',
#   '直接',
#   '面對',
#   '會員',
#   '的',
#   '人',
#   '的',
#   '任何',
#   '意見',
#   ' ',
#   ' ',
#   '只',
#   '聽',
#   '會員',
#   '或',
#   '其他',
#   '長官',
#   '的',
#   '單方面',
#   '投訴',
#   ' ',
#   '那',
#   '請問',
#   '還有',
#   '誰',
#   '敢接',
#   '這個',
#   '班',
#   '?',
#   ' ',
#   ' ',
#   '請',
#   '！',
#   '你',
#   '！',
#   '們',
#   '！',
#   '這',
#   '！',
#   '些',
#   '！',
#   '長',
#   '！',
#   '官',
#   '！',
#   '來',
#   '！',
#   '做',
#   '！',
#   '看',
#   '！',
#   '看',
#   '！',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '過來人'],
#  ['黑貓', '支援', '(', '๑', '•', '̀', 'ω', '•', '́', '๑', ')'],
#  ['B624', ' ', '妳', '想', '被', '這種', '人教', '？'],
#  ['不能',
#   '跟',
#   '宇凡',
#   '認真',
#   ' ',
#   '我',
#   '的',
#   'pt',
#   '也',
#   '超',
#   '相信',
#   '他',
#   ' ',
#   '結果',
#   'DKA',
#   '進來',
#   '兩次',
#   ' ',
#   '但是',
#   '出院',
#   '以後',
#   '依舊',
#   '把',
#   '宇凡',
#   '當成',
#   '女神',
#   ' ',
#   ' ',
#   '這個',
#   '人',
#   '醫學界',
#   '已經',
#   '呼籲',
#   '超',
#   '多次',
#   '的',
#   ' ',
#   '結果',
#   '民眾',
#   '還是',
#   '很',
#   '相信',
#   '她',
#   ' ',
#   '只要',
#   '碰到',
#   '她',
#   '的',
#   '粉絲',
#   ' ',
#   '衛教',
#   '幾乎',
#   '做',
#   '不',
#   '下去'],
#  ['看到',
#   '這篇',
#   '就',
#   '想起',
#   '前一陣子',
#   '的',
#   '強暴',
#   '風險係數',
#   '...',
#   ' ',
#   '把',
#   '我',
#   '在',
#   '那',
#   '篇',
#   '的',
#   '回應',
#   '修改',
#   '後',
#   '貼過來',
#   ' ',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   ' ',
#   '我們',
#   '都',
#   '知道',
#   '，',
#   '就是',
#   '有渣們',
#   '會',
#   '犯下',
#   '這些',
#   '令人髮指',
#   '的',
#   '事情',
#   '（',
#   '以',
#   '本篇',
#   '而言',
#   '，',
#   '就是',
#   '騷擾',
#   '、',
#   '性侵',
#   '.....',
#   '等等',
#   '）',
#   ' ',
#   ' ',
#   '犯罪',
#   '根本',
#   '就',
#   '防不勝防',
#   ' ',
#   '所以',
#   '現在',
#   '的',
#   '社會',
#   '只能',
#   '退而求其次',
#   ' ',
#   '宣導',
#   '大家',
#   '至少',
#   '做些',
#   '防範',
#   '，',
#   '讓',
#   '那些',
#   '渣們',
#   '覺得',
#   '選擇',
#   '侵犯',
#   '我',
#   '，',
#   '會',
#   '比較',
#   '棘手',
#   '、',
#   '比較',
#   '費工',
#   '而且',
#   '還更',
#   '難得',
#   '手',
#   ' ',
#   ' ',
#   '但',
#   '這',
#   '其實',
#   '是',
#   '一種',
#   '消極',
#   '的',
#   '做法',
#   '，',
#   '因為',
#   '我們',
#   '就是',
#   '無法',
#   '徹底',
#   '讓',
#   '這些',
#   '渣',
#   '從',
#   '社會',
#   '上',
#   '消失',
#   ' ',
#   '所以',
#   '只能',
#   '消極',
#   '的',
#   '要求',
#   '大家',
#   '注意',
#   '自保',
#   '，',
#   '因此',
#   '還是',
#   '會',
#   '有',
#   '倒楣',
#   '到',
#   '極致',
#   '的',
#   '受害者',
#   '出現',
#   '，',
#   '但',
#   '至少',
#   '有',
#   '注意',
#   '有',
#   '自保',
#   '的',
#   '人',
#   '就',
#   '不會',
#   '被',
#   '當成',
#   '目標',
#   ' ',
#   ' ',
#   '該',
#   '怎麼',
#   '說',
#   '......',
#   '就是',
#   '一種',
#   '把',
#   '不幸',
#   '推給',
#   '別人',
#   '去',
#   '承受',
#   '的',
#   '概念',
#   '吧',
#   ' ',
#   '對於',
#   '這種',
#   '所謂',
#   '“',
#   '保護',
#   '自己',
#   '”',
#   '的',
#   '宣導',
#   '，',
#   '幾乎',
#   '大家',
#   '都',
#   '會',
#   '接受',
#   '的',
#   '，',
#   '至少',
#   '這樣',
#   '受害者',
#   '不會',
#   '是',
#   '我',
#   ' ',
#   '畢竟',
#   '在',
#   '你',
#   '我',
#   '都',
#   '無力',
#   '阻止',
#   '、',
#   '都',
#   '是',
#   '受害者',
#   '備選',
#   '者',
#   '的',
#   '狀況',
#   '下',
#   '，',
#   '這',
#   '就是',
#   '個',
#   '很',
#   '合乎',
#   '人性',
#   '的',
#   '選擇',
#   ' ',
#   ' ',
#   '但是',
#   '我',
#   '無法',
#   '接受',
#   '有些',
#   '人',
#   '開始',
#   '把',
#   '自己',
#   '懂得',
#   '保護',
#   '當成',
#   '理所當然',
#   '，',
#   '而',
#   '開始',
#   '去',
#   '譴責',
#   '受害者',
#   ' ',
#   ' ',
#   '他們',
#   '忘記',
#   '了',
#   '這些',
#   '所謂',
#   '自我',
#   '保護',
#   '的',
#   '舉動',
#   '，',
#   '其實',
#   '是',
#   '建立',
#   '在',
#   '犧牲',
#   '那個',
#   '人',
#   '的',
#   '權利',
#   '上',
#   '(',
#   '最',
#   '淺顯易懂',
#   '的',
#   '就',
#   '像是',
#   '這',
#   '篇文章',
#   '中',
#   '提到',
#   '的',
#   '穿著',
#   '打扮',
#   ')',
#   ' ',
#   '他們',
#   '開始',
#   '認為',
#   '犧牲',
#   '這些',
#   '權利',
#   '來自',
#   '我',
#   '保護',
#   '，',
#   '是',
#   '一件',
#   '正確',
#   '的',
#   '事情',
#   ' ',
#   '他們',
#   '把',
#   '這',
#   '明明',
#   '只是',
#   '不得已',
#   '的',
#   '折衷方案',
#   '，',
#   '當成',
#   '"',
#   '"',
#   '必須',
#   '的',
#   '"',
#   '"',
#   '去',
#   '吹捧',
#   ' ',
#   ' ',
#   '這會',
#   '造成',
#   '甚麼',
#   '問題',
#   '?',
#   ' ',
#   '1',
#   '.',
#   ' ',
#   ' ',
#   '身為',
#   '可能',
#   '被',
#   '當成',
#   '目標',
#   '的',
#   '族群',
#   '，',
#   '所',
#   '擁有',
#   '的',
#   '權利',
#   '會',
#   '越來越少',
#   '，',
#   '但是',
#   '即使',
#   '付出',
#   '了',
#   '這些',
#   '代價',
#   '，',
#   '還是',
#   '一樣',
#   '危險',
#   ' ',
#   '就',
#   '像是',
#   '回教',
#   '世界',
#   '那樣',
#   '，',
#   '女性',
#   '這個',
#   '最',
#   '廣大',
#   '的',
#   '受害者',
#   '族群',
#   '，',
#   '擁有',
#   '的',
#   '權利',
#   '被',
#   '剝奪',
#   '的',
#   '所剩無幾',
#   '，',
#   '但是',
#   '性侵',
#   '事件',
#   '依舊',
#   '屢見不鮮',
#   ' ',
#   '我',
#   '不',
#   '懂',
#   '為',
#   '什麼',
#   '許多',
#   '人',
#   '看到',
#   '了',
#   '這樣',
#   '血淋淋',
#   '的',
#   '例子',
#   '，',
#   '還是',
#   '會',
#   '覺得',
#   '要求',
#   '"',
#   '"',
#   '可能',
#   '被',
#   '當成',
#   '目標',
#   '的',
#   '族群',
#   '"',
#   '"',
#   '限縮',
#   '權利',
#   '，',
#   '是',
#   '一件',
#   '理所當然',
#   '的',
#   '事情',
#   ' ',
#   ' ',
#   '2',
#   '.',
#   ' ',
#   '鼓勵',
#   '潛在',
#   '加害者',
#   ' ',
#   '當',
#   '我們',
#   '都',
#   '認同',
#   '是',
#   '受害者',
#   '穿太少',
#   '，',
#   '自己',
#   '出入',
#   '不',
#   '安全',
#   '環境',
#   '才',
#   '增加',
#   '風險',
#   '時',
#   ' ',
#   '其實',
#   '就是',
#   '在',
#   '幫',
#   '加害者',
#   '卸責',
#   '，',
#   '製造',
#   '一種',
#   '「',
#   '如果',
#   '當初',
#   '受害者',
#   '沒有',
#   '這樣',
#   '做',
#   '，',
#   '那',
#   '這位',
#   '受害者',
#   '受害',
#   '有',
#   '部分',
#   '就是',
#   '咎由自取',
#   '」',
#   '的',
#   '暗示',
#   ' ',
#   '所以',
#   '一位',
#   '潛在',
#   '加害者',
#   '看到',
#   '有位',
#   '目標',
#   '不',
#   '符合',
#   '這些',
#   '條件',
#   '時',
#   '，',
#   '就',
#   '會',
#   '覺得',
#   '“',
#   '那',
#   '我',
#   '有',
#   '衝動',
#   '想',
#   '侵犯',
#   '騷擾',
#   '他',
#   '也',
#   '是',
#   '情有可原',
#   '，',
#   '誰',
#   '叫',
#   '他',
#   '要來',
#   '夜店',
#   '跳舞',
#   '，',
#   '誰',
#   '叫',
#   '他',
#   '要',
#   '穿',
#   '得',
#   '那麼',
#   '欠幹',
#   '”',
#   ' ',
#   '讓',
#   '潛在',
#   '加害者',
#   '更',
#   '不會',
#   '受到',
#   '良心',
#   '拘束',
#   '，',
#   '因為',
#   '他',
#   '的',
#   '認知',
#   '告訴',
#   '了',
#   '他',
#   '，',
#   '受害者',
#   '自己',
#   '也',
#   '在',
#   '誘惑',
#   '我',
#   ' ',
#   '這',
#   '其實',
#   '就是',
#   '在',
#   '鼓勵',
#   '那些',
#   '潛在',
#   '加害者',
#   '作姦',
#   '犯科',
#   ' ',
#   ' ',
#   ' ',
#   '3',
#   '.',
#   ' ',
#   '加害者',
#   '更加',
#   '肆無忌憚',
#   ' ',
#   '社會風氣',
#   '譴責',
#   '受害者',
#   '沒有',
#   '保護',
#   '自己',
#   '，',
#   '替',
#   '加害者',
#   '卸責',
#   ' ',
#   '導致',
#   '受害者',
#   '不敢',
#   '發聲',
#   ' ',
#   '我',
#   '不',
#   '發聲',
#   '，',
#   '我',
#   '受到',
#   '的',
#   '傷害',
#   '"',
#   '"',
#   '只有',
#   '"',
#   '"',
#   '被',
#   '性侵',
#   ' ',
#   '我',
#   '發聲',
#   '了',
#   '，',
#   '我',
#   '受到',
#   '的',
#   '傷害',
#   '變成',
#   '是',
#   '被',
#   '性侵',
#   '+',
#   '被',
#   '輿論',
#   '、',
#   '親朋好友',
#   '責罵',
#   '鄙視',
#   ' ',
#   '所以',
#   '多數',
#   '的',
#   '受害者',
#   '選擇',
#   '了',
#   '不',
#   '發聲',
#   ' ',
#   ' ',
#   '這讓',
#   '加害者',
#   '更加',
#   '肆無忌憚',
#   '，',
#   '反正',
#   '沒人會',
#   '舉發',
#   '我',
#   ' ',
#   '或者說',
#   '要',
#   '舉發',
#   '我',
#   '也',
#   '要',
#   '等到',
#   '她',
#   '的',
#   '心理',
#   '建設',
#   '足夠',
#   '了',
#   '才',
#   '有',
#   '可能',
#   '(',
#   '搞不好',
#   '一輩子',
#   '都',
#   '不會',
#   '呢',
#   ')',
#   ' ',
#   '沒有',
#   '制裁',
#   '，',
#   '發現',
#   '這樣',
#   '做',
#   '我',
#   '爽',
#   '而且',
#   '還',
#   '不會',
#   '被',
#   '怎麼樣',
#   ' ',
#   '根本就是',
#   '犯罪',
#   '天堂',
#   '啊',
#   '!',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '就',
#   '現行',
#   '的',
#   '法律',
#   '制度',
#   '社會',
#   '公權力',
#   '執行',
#   '強度',
#   '來看',
#   '，',
#   '我們',
#   '很',
#   '可能',
#   '拿',
#   '"',
#   '"',
#   '牠',
#   '們',
#   '"',
#   '"',
#   '沒輒',
#   '（',
#   '看看',
#   '林奕含',
#   '.....',
#   '）',
#   ' ',
#   '而且',
#   '傷害',
#   '已',
#   '造成',
#   '時',
#   '，',
#   '再',
#   '多',
#   '的',
#   '處罰',
#   '都',
#   '無法彌補',
#   ' ',
#   '所以',
#   '我',
#   '還是',
#   '會',
#   '跟',
#   '身邊',
#   '親朋好友',
#   '宣導',
#   '這些',
#   '自我',
#   '防範',
#   '的',
#   '重要性',
#   ' ',
#   '即便',
#   '這是',
#   '在',
#   '閹割',
#   '我們',
#   '的',
#   '權利',
#   '，',
#   '在',
#   '目前',
#   '拿',
#   '他們',
#   '沒輒',
#   '的',
#   '狀況',
#   '下',
#   '，',
#   '我們',
#   '也',
#   '只能',
#   '妥協',
#   ' ',
#   '就算',
#   '這是',
#   '一種',
#   '將',
#   '罪犯',
#   '目標',
#   '轉移',
#   '到',
#   '比',
#   '我們',
#   '更',
#   '不',
#   '幸運',
#   '、',
#   '沒',
#   '機會',
#   '接受',
#   '這些',
#   '教育',
#   '的',
#   '人',
#   '身上',
#   '的',
#   '行為',
#   '，',
#   '我',
#   '還是',
#   '會',
#   '自私',
#   '的',
#   '選擇',
#   '這樣',
#   '做',
#   ' ',
#   ' ',
#   '但是',
#   '!',
#   '!',
#   ' ',
#   '同時',
#   '我會',
#   '一併',
#   '的',
#   '告訴',
#   '大家',
#   '，',
#   '這樣',
#   '選擇',
#   '的',
#   '前因後果',
#   '，',
#   '並且',
#   '"',
#   '"',
#   '宣導',
#   '不',
#   '應該',
#   '責怪',
#   '受害者',
#   '的',
#   '觀念',
#   '"',
#   '"',
#   ' ',
#   '因為',
#   '他們',
#   '會',
#   '受害',
#   '，',
#   '我們',
#   '也',
#   '是',
#   '助長',
#   '的',
#   '原因',
#   '之一',
#   ' ',
#   '如果',
#   '不是',
#   '我們',
#   '幸運',
#   '，',
#   '有',
#   '這樣',
#   '的',
#   '社經',
#   '地位',
#   '讓',
#   '我們',
#   '有',
#   '辦法',
#   '保護',
#   '自己',
#   '，',
#   '讓',
#   '我們',
#   '有',
#   '辦法',
#   '把',
#   '風險',
#   '轉移',
#   '到',
#   '他們',
#   '身上',
#   '，',
#   '我們',
#   '也',
#   '會',
#   '是',
#   '受害者',
#   ' ',
#   ' ',
#   '所以',
#   '我',
#   '無法',
#   '接受',
#   '許多',
#   '人',
#   '，',
#   '站',
#   '在',
#   '幸運',
#   '的',
#   '社經',
#   '地位',
#   '，',
#   '去',
#   '嘲弄',
#   '、',
#   '鄙視',
#   '、',
#   '責怪',
#   '這些',
#   '受害者',
#   '，',
#   '獲取',
#   '自己',
#   '內心',
#   '的',
#   '優越感',
#   '與',
#   '安全感',
#   ' ',
#   '真的',
#   '覺得',
#   '這樣',
#   '的',
#   '心態',
#   '很',
#   '噁心',
#   ' ',
#   '但',
#   '可悲',
#   '的',
#   '是',
#   '許多',
#   '人',
#   '就',
#   '都',
#   '這樣',
#   '.......',
#   ' ',
#   ' ',
#   '真的',
#   '不要',
#   '把',
#   '自身',
#   '的',
#   '幸運',
#   '當成',
#   '是',
#   '自己',
#   '的',
#   '能力',
#   '、',
#   '智慧',
#   '、',
#   '英明',
#   ' ',
#   '然後',
#   '繼續',
#   '在',
#   '網路上',
#   '大放厥詞',
#   '製造',
#   '二次',
#   '傷害',
#   ' ',
#   '我們',
#   '就',
#   '只是',
#   '比較',
#   '幸運',
#   '一點',
#   '罷了',
#   '....',
#   ' ',
#   ' ',
#   '宣導',
#   '自我',
#   '防範',
#   '的',
#   '前因後果',
#   '，',
#   '不',
#   '應該',
#   '責備',
#   '沒有',
#   '防範',
#   '的',
#   '人',
#   ' ',
#   '應該',
#   '是',
#   '一件',
#   '跟',
#   '宣導',
#   '自我',
#   '防範',
#   '一樣',
#   '重要',
#   '的',
#   '事情',
#   ' ',
#   '但是',
#   '看起來',
#   '，',
#   '這方面',
#   '宣導',
#   '的',
#   '成效',
#   '，',
#   '前者',
#   '遠遠',
#   '不及',
#   '後者',
#   '......',
#   ' ',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   '—',
#   ' ',
#   '這篇',
#   '留言',
#   '已經',
#   '好多',
#   '了',
#   ...],
#  ['挖',
#   '耖',
#   ' ',
#   '你',
#   '這種',
#   '人還',
#   '一堆',
#   '女',
#   '的',
#   '支持',
#   '你',
#   ' ',
#   ' ',
#   '看來',
#   '台女',
#   '沒救',
#   '了'],
#  ['超負荷'],
#  ['我',
#   '覺得',
#   '重點',
#   '不是',
#   '約',
#   '不',
#   '約',
#   '啊',
#   '而是',
#   '安全措施',
#   ' ',
#   '你',
#   '跟',
#   '炮友',
#   '手牽手',
#   '一起',
#   '去',
#   '做',
#   '檢查',
#   '再',
#   '開房',
#   '帶套',
#   ' ',
#   '和',
#   '跟',
#   '男',
#   '(',
#   '女',
#   ')',
#   '友',
#   '不',
#   '檢查',
#   '不帶',
#   '套',
#   '做',
#   ' ',
#   '請問',
#   '哪個',
#   '比較',
#   '容易',
#   '中標',
#   '?',
#   ' ',
#   '有',
#   '的',
#   '時候',
#   '覺得',
#   '這種',
#   '約炮',
#   '勸世文',
#   '真的',
#   '搞錯',
#   '重點',
#   ' ',
#   '重點',
#   '不是',
#   '跟',
#   '誰',
#   '做',
#   '或者',
#   '跟',
#   '多少',
#   '人',
#   '做',
#   '或',
#   '認',
#   '不',
#   '認識',
#   ' ',
#   '而是',
#   '做',
#   '之前',
#   '的',
#   '安全措施',
#   ' ',
#   '搞清楚',
#   '彼此',
#   '的',
#   '身體狀況',
#   '為',
#   '先',
#   '，',
#   ' ',
#   '再者',
#   '注意',
#   '防護',
#   '措施',
#   '，',
#   ' ',
#   '這樣',
#   '做',
#   '的話',
#   '，',
#   '約',
#   '或非',
#   '約',
#   '的',
#   '風險',
#   '不',
#   '就',
#   '都',
#   '一樣',
#   '低',
#   '了',
#   '嗎',
#   '?',
#   ' ',
#   ' ',
#   '我',
#   '自己',
#   '不',
#   '約',
#   '，',
#   '但',
#   '我',
#   '覺得',
#   '不用',
#   '妖魔化',
#   '約炮',
#   ' ',
#   '更',
#   '不用',
#   '一副',
#   '苦口婆心',
#   '的',
#   '樣子',
#   '覺得',
#   '必須',
#   '感化',
#   '世人',
#   ' ',
#   '就',
#   '像',
#   ' ',
#   'b12',
#   ' ',
#   '說',
#   '的',
#   '尊重',
#   '很',
#   '重要',
#   ' ',
#   '這位',
#   '護理',
#   '老師',
#   '(',
#   '其實',
#   '不太信',
#   ')',
#   '也許',
#   '真的',
#   '有所',
#   '感悟',
#   ' ',
#   '但',
#   '我',
#   '覺得',
#   '她',
#   '搞錯',
#   '重點',
#   '，',
#   '而且',
#   '有些',
#   '多管閒事',
#   '了',
#   ' ',
#   '約炮',
#   '不是',
#   '高風險',
#   '行為',
#   '，',
#   '不',
#   '做好',
#   '安全措施',
#   '才',
#   '是'],
#  ['哈',
#   ' ',
#   '笑',
#   '了',
#   ' ',
#   '對',
#   '了',
#   ' ',
#   ' ',
#   '怎麼',
#   '每個',
#   '胖子',
#   '都',
#   '是',
#   '因為',
#   '生病',
#   '才',
#   '瘦',
#   '不',
#   '下來',
#   '？'],
#  ['不是',
#   '把',
#   '自己',
#   '弄',
#   '得',
#   '跟',
#   '世界',
#   '不',
#   '一樣',
#   '就是',
#   '有',
#   '自信',
#   '就是',
#   '做',
#   '自己'],
#  ['好文', '推', ' ', '願', '更', '多', '人', '看到', '且', '關注'],
#  ['連',
#   '房子',
#   '都',
#   '沒',
#   '看到',
#   '就',
#   '租',
#   '真的',
#   '太',
#   '危險',
#   '了',
#   ' ',
#   ' ',
#   '那個',
#   '發霉牆',
#   '是',
#   '你',
#   '進去',
#   '之前',
#   '就',
#   '有',
#   '的',
#   '嗎',
#   '？',
#   '如果',
#   '是',
#   '那',
#   '房東',
#   '當初',
#   '有',
#   '承諾',
#   '處理',
#   '嗎',
#   '？',
#   '還是',
#   '有',
#   '漏水',
#   '滲水',
#   '問題',
#   '？',
#   '如果',
#   '是',
#   '之後',
#   '才',
#   '發霉',
#   '的',
#   ' ',
#   '其實',
#   '中壢',
#   '這裡',
#   '真的',
#   '很難',
#   '找到',
#   '不濕',
#   '的',
#   '房子',
#   ' ',
#   '只有',
#   '分不太濕',
#   '跟',
#   '真的',
#   '很濕',
#   ' ',
#   '最好',
#   '買台',
#   '除',
#   '濕機',
#   ' ',
#   '但',
#   '如果',
#   '是',
#   '房東',
#   '都',
#   '不',
#   '處理',
#   '的話',
#   '真的',
#   '滿',
#   '誇張',
#   '的',
#   '...'],
#  ['閉嘴'],
#  ['B32',
#   ' ',
#   '?',
#   '?',
#   '?',
#   ' ',
#   '我',
#   '不能',
#   '說',
#   '異性戀',
#   '有',
#   '愛滋',
#   '?',
#   ' ',
#   '自己',
#   '在',
#   '那邊',
#   '自以',
#   '為',
#   '腦補',
#   ' ',
#   '還',
#   '自稱',
#   '白癡',
#   ' ',
#   ' ',
#   '厲害'],
#  ['B155',
#   ' ',
#   '這些',
#   '女森',
#   '真的',
#   '很',
#   '可怖',
#   '，',
#   '跟',
#   '大陸',
#   '大媽',
#   '一樣',
#   '瘋狂',
#   '，',
#   '我先',
#   '閃拉',
#   '，',
#   '你',
#   '一個',
#   '人',
#   '獨自',
#   '奮戰',
#   '，',
#   '加油',
#   '！',
#   '這些',
#   '迷妹',
#   '很',
#   '團結',
#   '的',
#   '，',
#   '但',
#   '我',
#   '相信',
#   '你',
#   '一個',
#   '人',
#   '也',
#   '行',
#   '的',
#   '！'],
#  ['我家',
#   '跟',
#   '你家',
#   '一樣',
#   '，',
#   '重點',
#   '是',
#   '我',
#   '有',
#   '4',
#   '個',
#   '兄弟',
#   '要',
#   '伺候',
#   '，',
#   '之前',
#   '也',
#   '跟',
#   '父母',
#   '吼過',
#   '他們',
#   '，',
#   '只有',
#   '換來',
#   '弟',
#   '暴力',
#   '相向',
#   '（',
#   '會',
#   '動手',
#   '的',
#   '根本',
#   '廢物',
#   '）'],
#  ['看到',
#   '他',
#   '的',
#   '頭髮',
#   ' ',
#   '再配',
#   '那個',
#   '帽子',
#   ' ',
#   ' ',
#   '我',
#   '就',
#   '不想',
#   '看',
#   '了'],
#  ['怎麼',
#   '有',
#   '你',
#   '這種',
#   '人',
#   '啊',
#   '？',
#   '一堆',
#   '人選',
#   '不到',
#   '結果',
#   '因為',
#   '你',
#   '自己',
#   '懶',
#   '就',
#   '棄選',
#   '？',
#   '去',
#   '吃屎',
#   '好不好'],
#  ['明明',
#   '就是',
#   '設計',
#   '參考',
#   '，',
#   '「',
#   '參考',
#   '」',
#   '而已',
#   '，',
#   '把',
#   '這',
#   '當真',
#   '下去',
#   '評論',
#   '，',
#   '那個',
#   '網友',
#   '是',
#   '嗑',
#   '太',
#   '多',
#   '了',
#   '吧',
#   '，',
#   '然後',
#   '其他',
#   '有',
#   '跟',
#   '著講',
#   '的',
#   '人',
#   '也',
#   '是',
#   '白癡',
#   '一個',
#   '。',
#   '還有',
#   '華中',
#   '的',
#   '，',
#   '乾',
#   '你',
#   'ㄆ',
#   '事'],
#  ['因為',
#   '濕',
#   '敷',
#   '導致',
#   '角質層',
#   '軟化',
#   '看起來',
#   '才',
#   '這麼',
#   '迅速',
#   '有效',
#   '哦',
#   '…',
#   '…'],
#  ['更差',
#   '的',
#   '是',
#   '退錢',
#   '也',
#   '補償',
#   '不了',
#   '滿滿的',
#   '空虛',
#   '啊',
#   '...',
#   ' ',
#   ' ',
#   '以為',
#   '大家',
#   '在意',
#   '的',
#   '是',
#   '錢',
#   '嗎',
#   ' ',
#   '錯',
#   '！',
#   '是',
#   '滿懷',
#   '期待',
#   '然後',
#   '被',
#   '打壞',
#   '心情',
#   ' ',
#   '再來',
#   '怪罪',
#   '盒子',
#   '=',
#   '=',
#   ' ',
#   '難不成',
#   '我們',
#   '應該',
#   '去',
#   '找',
#   '盒子',
#   '理論',
#   '嗎',
#   '？',
#   '？',
#   '？'],
#  ['真的',
#   '很會',
#   '自己',
#   '說',
#   '故事',
#   '欸',
#   '哈哈哈',
#   '哈哈',
#   ' ',
#   ' ',
#   '什麼',
#   '都',
#   '聽說',
#   '，',
#   '聽說',
#   '你',
#   '手機',
#   '用',
#   'HTC',
#   '哦',
#   '，',
#   '窮鬼',
#   '。'],
#  ['男', '的', '就', '賤', ' ', '乖乖', '認命', '吧', '哈哈哈'],
#  ['你還', '幼稚園', '嗎', ' ', '這種', '小事', '也', '要', 'po', '上來', ' ', '廢文'],
#  ['SHINee',
#   '是',
#   '我',
#   '的',
#   '初心',
#   '啊',
#   'QQQQ',
#   ' ',
#   '想想',
#   '國中',
#   '的',
#   '時候',
#   '都',
#   '會',
#   '因為',
#   '別人',
#   '把',
#   '閃尼',
#   '的',
#   '英文',
#   '打錯',
#   '而',
#   '生氣',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':',
#   ' ',
#   '然後',
#   '國二',
#   '就',
#   '衝小',
#   '巨蛋',
#   '看',
#   '演唱會',
#   '，',
#   '好像',
#   '是',
#   '一巡',
#   '吧',
#   '（',
#   '？',
#   ' ',
#   '雖然',
#   '現在',
#   '淡出',
#   '韓圈',
#   '了',
#   '但',
#   '還是',
#   '默默',
#   '關注',
#   ':',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'smiling',
#   '_',
#   'eyes',
#   ':',
#   ' ',
#   '看',
#   '完',
#   '這文',
#   '真的',
#   '好懷念',
#   '啊',
#   '哈哈哈'],
#  ['B5', ' ', '放心', '，', '人', '對', '了', '事', '就', '對'],
#  ['無聊', '，', '玻璃'],
#  ['甲鬼甲怪', ' ', '買根', '按摩棒', '互肛', '不會', '？'],
#  ['我',
#   '好',
#   '想',
#   '吃',
#   ' ',
#   '錐',
#   'get',
#   ' ',
#   'out',
#   '（',
#   '水餃',
#   '）',
#   ':',
#   'face',
#   '_',
#   'savoring',
#   '_',
#   'food',
#   ':'],
#  ['B13', ' ', '太猛', '了', '疾管署', '的', '資料', '都', '說', '不能', '信'],
#  ['破麻', '閉嘴'],
#  ["'", "'", '祂', "'", "'", '開心', '的', '合不攏嘴', '？', '？', '？', '？', '？', '？'],
#  ['對',
#   '啊',
#   ' ',
#   '敏惠',
#   '沒',
#   '帥哥',
#   ' ',
#   '只有',
#   '一堆',
#   '噁心',
#   '的',
#   ' ',
#   'T',
#   ' ',
#   'and',
#   ' ',
#   'G'],
#  ['會計',
#   '？',
#   '呵呵',
#   ' ',
#   '有',
#   '一位',
#   '大四',
#   '的',
#   '吧',
#   ' ',
#   '女朋友',
#   '貌似',
#   '是',
#   '企管',
#   '的',
#   '‘',
#   '女神',
#   '’',
#   ' ',
#   '我',
#   '看',
#   '還是',
#   '算了吧',
#   ' ',
#   'ㄏ',
#   'ㄏ'],
#  ['之前',
#   '跟',
#   '男友',
#   '也',
#   '暫時',
#   '分開',
#   ' ',
#   '現在',
#   '也',
#   '幸福',
#   '的',
#   '在',
#   '一起',
#   '五年',
#   '了',
#   '哦',
#   ':',
#   'red',
#   '_',
#   'heart',
#   ':',
#   '️',
#   ' ',
#   '原',
#   'po',
#   '加油',
#   ':',
#   'flexed',
#   '_',
#   'biceps',
#   ':',
#   ' ',
#   ' ',
#   ' ',
#   '-',
#   '楊洋',
#   '的',
#   '地下',
#   '情人'],
#  ['每個',
#   '人',
#   '對',
#   '緊急狀況',
#   '的',
#   '應變能力',
#   '又',
#   '不同',
#   ' ',
#   '有',
#   '冷靜',
#   '的',
#   '也',
#   '會',
#   '有',
#   '緊張',
#   '的',
#   ' ',
#   '不要',
#   '都',
#   '覺得',
#   '別人',
#   '應該',
#   '要',
#   '怎樣',
#   ' ',
#   '如果',
#   '你',
#   '有',
#   '能力',
#   '就',
#   '多',
#   '幫忙',
#   '一些'],
#  ['For',
#   ' ',
#   'you',
#   '這首超',
#   '好聽',
#   '！',
#   '！',
#   ' ',
#   '附上',
#   '現場',
#   '演唱',
#   '版',
#   ' ',
#   '可以',
#   '聽聽看',
#   ':',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'heart',
#   '-',
#   'eyes',
#   ':',
#   ' ',
#   ' '],
#  ['B248',
#   '會',
#   '啊',
#   ' ',
#   '檢討',
#   '自己',
#   '穿太少',
#   '之外',
#   ' ',
#   '還要',
#   '檢討',
#   '不夠',
#   '壯',
#   '。',
#   ' ',
#   '不過',
#   '反過來',
#   '檢討',
#   '女生',
#   '不夠',
#   '壯',
#   '，',
#   '不會',
#   '防身術',
#   '大概',
#   '會',
#   '被',
#   '批鬥',
#   '到',
#   '死',
#   '呵呵'],
#  ['小明',
#   '走',
#   '在',
#   '路上',
#   '看到',
#   'ㄧ',
#   '坨',
#   '大便',
#   ' ',
#   '但',
#   '他',
#   '不',
#   '確定',
#   '是',
#   '大便',
#   ' ',
#   '結果',
#   '就',
#   '用',
#   '手',
#   '沾',
#   '一沾放',
#   '嘴巴',
#   '確定',
#   '是不是',
#   ' ',
#   '試',
#   '了',
#   '之後',
#   '馬上',
#   '說',
#   ' ',
#   '哈哈',
#   '真的',
#   '是',
#   '大便',
#   '還好',
#   '沒',
#   '踩到'],
#  ['我們',
#   '家',
#   '的',
#   '也',
#   '是',
#   '非常',
#   '的',
#   '妖嬌',
#   ' ',
#   '但',
#   '牠',
#   '是',
#   '公',
#   '的',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':',
#   ' '],
#  ['一個',
#   '人',
#   '吃',
#   '好吃',
#   '的',
#   ' ',
#   '很',
#   '好',
#   '啊',
#   '，',
#   '慢慢',
#   '吃',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':'],
#  ['誰', '在', '說', '電機系', '是', '肥宅', '的', '我', '跟', '他', '拼命'],
#  ['既然',
#   '是',
#   '不好',
#   '的',
#   '事情',
#   '，',
#   '也',
#   '不願',
#   '大家',
#   '靠近',
#   '，',
#   '也',
#   '代表',
#   '危險',
#   '，',
#   '不',
#   '更',
#   '應該',
#   '跟',
#   '大家',
#   '說',
#   '嗎',
#   '?'],
#  ['那個',
#   '卡稱',
#   '的',
#   '就',
#   '以',
#   '消費',
#   '人家',
#   '而紅',
#   ' ',
#   ' ',
#   '一個',
#   '的',
#   '成就',
#   '如何',
#   '根本',
#   '不',
#   '乾性',
#   '向',
#   '屁事',
#   ' ',
#   ' ',
#   '之前',
#   '也',
#   '消費',
#   '各種',
#   '男星',
#   '說',
#   '誰',
#   'Gay',
#   '怎樣',
#   '的',
#   ' ',
#   ' ',
#   '掰',
#   '故事',
#   '被',
#   '打',
#   '臉還',
#   '直接',
#   '假裝',
#   '沒',
#   '看到',
#   ' ',
#   ' ',
#   '還',
#   '跟風',
#   '戴假髮',
#   '拍照',
#   '上傳',
#   ' ',
#   ' ',
#   ' ',
#   '順便',
#   '副',
#   '他',
#   '自己',
#   '的',
#   'IG',
#   '給',
#   '人家',
#   '追蹤',
#   ' ',
#   ' ',
#   '不',
#   '懂',
#   '一堆',
#   '人',
#   '跟風',
#   '是',
#   '怎樣',
#   ' ',
#   ' ',
#   '他',
#   '超愛打',
#   '被',
#   '別人',
#   '歧視',
#   '裝',
#   '自己',
#   '很',
#   '可憐',
#   ' ',
#   ' ',
#   '想',
#   '詔告',
#   '天下',
#   '他',
#   '自己',
#   '被',
#   '歧視',
#   '怎樣',
#   '的',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'rolling',
#   '_',
#   'eyes',
#   ':',
#   '️'],
#  ['第一次', '是', '測試', ' ', '第二次', '就', '會', '真的', '上', '，', '小心', '居心不良'],
#  ['可能',
#   '叫',
#   '姊姊',
#   '就',
#   '代表',
#   ' ',
#   '原',
#   'po',
#   '真的',
#   '只是',
#   '作',
#   '愛心',
#   '吧',
#   ' ',
#   '算是',
#   '給',
#   '妹妹',
#   '一個',
#   '安心',
#   '?',
#   ' ',
#   '要',
#   '我',
#   '真的',
#   '很',
#   '感動',
#   ' ',
#   ' ',
#   '乾哥',
#   '乾爸',
#   '，',
#   '不管',
#   '哪個',
#   '都',
#   '聽',
#   '起來',
#   '都',
#   '還有',
#   '那個',
#   '意思',
#   '。'],
#  ['这', '不是', '流氓', '團嗎', '，', '咿', '？'],
#  ['整形', '怪物', '了解', '一下', ' '],
#  ['覺得',
#   '蠻業配',
#   '的',
#   ':',
#   'unamused',
#   '_',
#   'face',
#   ':',
#   ' ',
#   '帳號',
#   '店名',
#   '都',
#   '沒碼'],
#  ['2Max'],
#  ['為', '什麼', '要', '調戲', '阿姨'],
#  ['有沒有',
#   '關於',
#   '動保社',
#   '不回',
#   '訊息',
#   '，',
#   '還嗆',
#   '人',
#   '不要',
#   '私自',
#   '帶校',
#   '狗',
#   '處理',
#   '傷口',
#   '的',
#   '八卦'],
#  ['會',
#   ' ',
#   '超',
#   '喜歡',
#   ' ',
#   '看到',
#   '他',
#   '的',
#   '反應',
#   '都',
#   '覺得',
#   '很',
#   '可愛',
#   ':',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'heart',
#   '-',
#   'eyes',
#   ':',
#   ' ',
#   '至於',
#   '回',
#   '訊息',
#   '通常',
#   '每天',
#   '都',
#   '會',
#   '回',
#   ' ',
#   '不過',
#   '也',
#   '是',
#   '有',
#   '忘記',
#   '的',
#   '時候'],
#  ['你', '少畫', '木炭', '了'],
#  ['素顏',
#   '就是',
#   '用',
#   '不會',
#   '改變',
#   '臉部',
#   '顏色',
#   '的',
#   '東西',
#   '啊',
#   '~',
#   ' ',
#   '一般',
#   '透明',
#   '隱形眼鏡',
#   ' ',
#   '無',
#   '潤色',
#   '防曬',
#   ' ',
#   '無',
#   '潤色',
#   '護脣膏'],
#  ['好像',
#   '某種',
#   '動物',
#   '的',
#   '防衛',
#   '機制',
#   '哦',
#   ' ',
#   ' ',
#   '你',
#   '開',
#   '我門',
#   '我',
#   '就',
#   '對',
#   '你',
#   '射',
#   '東西'],
#  ['哎呀', ' ', '是', '葉佩玟'],
#  ['你',
#   '一個',
#   '大學生',
#   '這種',
#   '事',
#   '都',
#   '不',
#   '知道',
#   '怎麼辦',
#   '你',
#   '以後',
#   '要',
#   '怎麼',
#   '生活',
#   '？',
#   ' ',
#   '在',
#   '這裡',
#   '發文',
#   '不',
#   '蒐證',
#   '報警',
#   '，',
#   '其他人',
#   '也',
#   '只能',
#   '叫',
#   '你',
#   '蒐證',
#   '報警',
#   '，',
#   '問題',
#   '是',
#   '你',
#   '會',
#   '做',
#   '嗎',
#   '？',
#   ' ',
#   '還是',
#   '你',
#   '只是',
#   '想',
#   '找',
#   '人',
#   '幫助',
#   '你',
#   '把',
#   '你',
#   '也',
#   '爸',
#   '打',
#   '一頓',
#   '？'],
#  ['B5',
#   ' ',
#   '你',
#   '激動',
#   '什麼',
#   '阿',
#   '=',
#   '=',
#   ' ',
#   '出不出',
#   '道',
#   '也',
#   '不是',
#   '我們',
#   '或',
#   '練習生',
#   '可以',
#   '決定',
#   '的',
#   '好',
#   '嗎',
#   ' ',
#   '講話',
#   '不用',
#   '這麼',
#   '難聽'],
#  ['B26',
#   ' ',
#   '既然',
#   '要',
#   '追星',
#   '就',
#   '該',
#   '有',
#   '心理準備',
#   '沒',
#   '地方',
#   '坐',
#   '了',
#   '吧',
#   '？',
#   ' ',
#   '坐在',
#   '中間',
#   '影響',
#   '其他人',
#   '權利',
#   '，',
#   '這是',
#   '教育',
#   '的',
#   '問題',
#   '了',
#   ' ',
#   '懂嗎',
#   '？'],
#  ['可以', '談場', '不用', '負責', '的', '戀愛', '真幸福', '，', '祝你好運'],
#  ['勇迷敗', '人品'],
#  ['的', '啦', '的', '啦', '的', '啦', ' ', '加分', '加分', '加分', ' ', '喝酒', '啦'],
#  ['你',
#   '男友',
#   '可能',
#   '會',
#   '介意',
#   '自己',
#   '在',
#   '不知情',
#   '的',
#   '情況',
#   '下',
#   '手機',
#   '被',
#   '亂',
#   '發文',
#   '吧',
#   '，',
#   '也許',
#   '那',
#   '是',
#   '他',
#   '的',
#   '底線'],
#  ['你', '可以', '模仿', '他', '做成', '標語', ' ', '然後', '放在', '桌面', '提醒', '你'],
#  ['在', '經管', '面前', '誰', '敢秀', '下限', '？'],
#  ['B1', ' ', '講話', '別', '那麼', '難聽', '好', '嗎'],
#  ['周', '學年', '到底', '?', '?', '?', '?', '?'],
#  ['B759', ' ', '這裡', '不是', '自由言論', '區嗎', ' ', '不爽', '別', '來看', '留言', '啊'],
#  ['B2', ' ', '就', '憑', '你', '連字', '都', '打錯'],
#  ['哈哈',
#   '我國',
#   '中',
#   '太閒',
#   '被',
#   '到',
#   '100',
#   '為',
#   '，',
#   '我還',
#   '沒',
#   '遇過',
#   '有人',
#   '背',
#   '的',
#   '比',
#   '我',
#   '多',
#   '(',
#   '自豪',
#   '~',
#   '~'],
#  ['好', '恐怖', '，', '直接', '封鎖', '不', '就', '好', '了', '?'],
#  ['他', '才', '高三', '思想', '本來', '就還', '未成熟', '...'],
#  ['有人',
#   '會信',
#   '這個',
#   '我',
#   '也',
#   '是',
#   '笑笑',
#   '的',
#   ' ',
#   '再',
#   '看看',
#   '學校',
#   '....',
#   '笑',
#   '而',
#   '不語'],
#  ['原來', '是', '古蹟', '啊', '，', '我', '以', '為', '是', '教育', '機構', '呢', '@', '@'],
#  ['ㄏ',
#   'ㄏ',
#   ' ',
#   '如果',
#   '沒',
#   '後續',
#   '她',
#   '的確',
#   '無辜',
#   ' ',
#   '但',
#   '她',
#   '繼續',
#   '做',
#   '了',
#   '那些',
#   '公開',
#   '的',
#   '動作',
#   ' ',
#   '真的',
#   '就',
#   '沒',
#   '辦法',
#   '體諒',
#   '她',
#   '覺得',
#   '她',
#   '是',
#   '無辜',
#   '的',
#   '了',
#   ' ',
#   '你',
#   '說',
#   '她',
#   '有',
#   '崩潰',
#   '的',
#   '權利',
#   ' ',
#   '那',
#   '原原',
#   'po',
#   '呢',
#   '？'],
#  ['B8', ' ', '無知', '還不', '自知', '才', '讓', '人', '害怕', ' ', '唉'],
#  ['她', '就是', '個', '喜歡', '吃韓', '屌', '的', '婊', ' ', '思想', '超北爛'],
#  ['我',
#   '是',
#   '不管',
#   '誰',
#   '當選',
#   '啦',
#   ' ',
#   '當上',
#   '又',
#   '如何',
#   '？',
#   ' ',
#   '上',
#   '一屆',
#   '如同',
#   '企管',
#   '所說',
#   '唉',
#   ' ',
#   '商管',
#   '沒有',
#   '誰',
#   '是',
#   '會長',
#   ' ',
#   '誰',
#   '想當',
#   '會長',
#   '誰',
#   '就是',
#   '會長',
#   ' ',
#   '懂',
#   '？',
#   ' ',
#   '做個',
#   '形式',
#   '而已'],
#  ['B87',
#   ' ',
#   '看看',
#   'MAMAMOO',
#   '那集',
#   ':',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'heart',
#   '-',
#   'eyes',
#   ':',
#   ' ',
#   '就',
#   '知道',
#   '女團',
#   '實力',
#   '的',
#   '區別',
#   '了',
#   ':',
#   'smiling',
#   '_',
#   'face',
#   '_',
#   'with',
#   '_',
#   'smiling',
#   '_',
#   'eyes',
#   ':',
#   ' ',
#   ' ',
#   '-',
#   'moomoo'],
#  ['你',
#   '在',
#   '這種',
#   '匿名',
#   '的',
#   '地方',
#   '待久',
#   '了',
#   '才',
#   '會',
#   '想',
#   '跳樓',
#   '吧',
#   ' ',
#   '遠離',
#   '自殺',
#   '從',
#   '離開',
#   '匿名',
#   '論壇',
#   '開始'],
#  ['B394', ' ', ' ', '快到', '中午', '了', ' ', '想想', '要', '吃', '什麼'],
#  ['怒', '推', '107', '政法', '良朝瑋'],
#  ['要',
#   '馬',
#   '就',
#   '一',
#   '開始',
#   '就',
#   '說',
#   '，',
#   '要馬',
#   '就是',
#   '一輩子',
#   '不',
#   '要說',
#   '。',
#   '都',
#   '結婚',
#   '生小孩',
#   '才',
#   '說',
#   '根本',
#   'ㄏ',
#   'ㄏ',
#   '。',
#   '可憐',
#   '的',
#   '是',
#   '你媽',
#   '，',
#   '跟',
#   '到',
#   '了',
#   '一個',
#   '同性戀',
#   '，',
#   '生',
#   '下來',
#   '又',
#   '是',
#   '一個',
#   '同性戀',
#   '，',
#   '你',
#   '以後',
#   '跟',
#   '同性戀',
#   '結婚',
#   '，',
#   '媽啊',
#   '三個',
#   '同性戀',
#   '。'],
#  ['B83',
#   ' ',
#   '因為',
#   '我',
#   '開門',
#   '直接',
#   '看到',
#   '地上',
#   '一灘',
#   '血',
#   '我',
#   '真的',
#   '傻眼',
#   '～',
#   '畫面',
#   '上',
#   '不',
#   '明顯',
#   '但是',
#   '實際',
#   '看超',
#   '可怕',
#   '的',
#   '...'],
#  ['我',
#   '相信',
#   '一分錢',
#   '一分貨',
#   ' ',
#   ' ',
#   '不過',
#   '我',
#   '覺得',
#   '有些',
#   '不',
#   '需要',
#   '那麼',
#   '貴',
#   '也',
#   '可以',
#   '用',
#   '比較',
#   '便宜',
#   '的',
#   '替換',
#   ' ',
#   '我',
#   '個人',
#   '認為',
#   '不要',
#   '有',
#   '「',
#   '只有',
#   '專櫃',
#   '或是',
#   '名牌',
#   '最棒',
#   '」',
#   '的',
#   '迷思'],
#  ['請問',
#   '南開',
#   '都',
#   '是',
#   '垃圾',
#   '嗎',
#   ' ',
#   ' ',
#   '好像',
#   '是',
#   '哦',
#   ' ',
#   ' ',
#   '反正',
#   '南開',
#   '8',
#   '+',
#   '9',
#   '很多',
#   ' ',
#   '本來',
#   '就是',
#   '一群',
#   '垃圾',
#   '聚集',
#   '的',
#   '地方',
#   '了',
#   ' ',
#   ' ',
#   '不',
#   'EY'],
#  ['要'],
#  ['我',
#   '現在',
#   '在',
#   '上海',
#   '餐廳',
#   '工作',
#   '，',
#   '每次',
#   '要問',
#   '：',
#   '「',
#   '哪',
#   '一桌',
#   '?',
#   '」',
#   '，',
#   '我',
#   '都',
#   '差點',
#   '講成',
#   '：',
#   '「',
#   '哪',
#   '一床',
#   '?',
#   '」',
#   ':',
#   'loudly',
#   '_',
#   'crying',
#   '_',
#   'face',
#   ':',
#   ' ',
#   '(',
#   '以前',
#   '是',
#   '護理',
#   '師',
#   '...',
#   ')',
#   ' ',
#   '客人',
#   '變',
#   '病人',
#   '的',
#   '概念'],
#  ['不', '認識', '欸', '誰'],
#  ['低能兒',
#   ' ',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
#   '_',
#   'on',
#   '_',
#   'the',
#   '_',
#   'floor',
#   '_',
#   'laughing',
#   ':',
#   ':',
#   'rolling',
# ...
#   '唯独',
#   '个别',
#   '反华',
#   '台独',
#   '的',
#   '大',
#   '逆',
#   '子孙',
#   '，',
#   '不认',
#   '养育',
#   '自己',
#   '的',
#   '祖国',
#   '和',
#   '哺育',
#   '自己',
#   '的',
#   '文化',
#   '，',
#   '必然',
#   '遭到',
#   '世界',
#   '的',
#   '唾弃'],
#  ['你',
#   '不是',
#   '唯一',
#   '的',
#   '一個',
#   ' ',
#   '哈哈哈',
#   ' ',
#   '我',
#   '也',
#   '這麼',
#   '做過',
#   ' ',
#   '結果',
#   '遇到',
#   '一個',
#   '博士',
#   '還',
#   '碩士',
#   '高材生',
#   '推銷員',
#   ' ',
#   '英文',
#   '講的',
#   '不錯'],
#  ['畫了', '不少', '呢', '\u3000', '非常', '上癮', '\u3000', '眼睛', '也', '很', '痛'],
#  ['B20',
#   ' ',
#   '一方面',
#   '是',
#   '她',
#   '也',
#   '不',
#   '需要',
#   '我',
#   '幫',
#   '，',
#   '另一方面',
#   '嘛',
#   '...',
#   '你',
#   '不',
#   '覺得',
#   '很',
#   '有趣',
#   '嗎',
#   '，',
#   '看著',
#   '一個',
#   '小小',
#   '隻',
#   '的',
#   '女孩子',
#   '一邊',
#   '大聲',
#   '咒罵',
#   '一邊',
#   '移車',
#   '...',
#   'ㄆ',
#   'ㄆ',
#   '（',
#   '我',
#   '是',
#   '腹',
#   '黑',
#   '，',
#   '對',
#   '）'],
#  ['B19', ' ', '也', '有', '可能', '不會', '發炎', '啊'],
#  ['在',
#   '她',
#   '的',
#   '文章',
#   '底下',
#   ' ',
#   '留言',
#   '的',
#   '人',
#   '真的',
#   '知道',
#   '發生',
#   '什麼',
#   '事情',
#   '嗎',
#   '=',
#   '=',
#   ' ',
#   '就',
#   '只是',
#   '衛生',
#   '不好',
#   '很',
#   '噁',
#   ' ',
#   '人家',
#   '講',
#   '一下',
#   ' ',
#   '也',
#   '可以',
#   '一副',
#   '好像',
#   '大家',
#   '惡意',
#   '攻擊',
#   '她',
#   '?',
#   '?',
#   '?',
#   '?',
#   '?',
#   ' ',
#   'WTF',
#   ' ',
#   '還有',
#   '人',
#   '說',
#   '她',
#   'EQ',
#   '很',
#   '好',
#   '？'],
#  ['沒',
#   '辦法',
#   '，',
#   '這些',
#   '人',
#   '以後',
#   '就是',
#   '那種',
#   '吃飯',
#   '寫',
#   '不能',
#   '外包',
#   '還是',
#   '外包',
#   '一大',
#   '袋',
#   '的',
#   '大嬸',
#   '大叔'],
#  ['也', '太', '中', '二', ' ', '好', '可憐'],
#  ['B104', ' ', '當', '砲', '灰', '吧'],
#  ['看',
#   '了',
#   '各式',
#   '奇葩',
#   '留言',
#   '後',
#   ' ',
#   '我',
#   '贊同',
#   '你',
#   '的',
#   '想法',
#   '了',
#   ' ',
#   ' ',
#   '都',
#   '倒',
#   '一倒',
#   '吧',
#   '，',
#   '真是',
#   '有夠',
#   '可悲',
#   '的',
#   ' ',
#   '病入膏肓',
#   '了',
#   '還不',
#   '清醒',
#   ' ',
#   '那',
#   '我',
#   '想',
#   '就讓',
#   '他',
#   '死',
#   '透',
#   '吧'],
#  ['糞系', ' ', '丟臉'],
#  ['那些', '男生', '也', '蠻', '有', '問題', '的'],
#  ['鮪', '魚蛋', '餅', '一份'],
#  ['她',
#   '的',
#   '課',
#   '要是',
#   '沒',
#   '過',
#   '的話',
#   ' ',
#   '你',
#   '乾脆',
#   '從商',
#   '學院',
#   '頂樓',
#   '跳下去',
#   '好',
#   '了',
#   '.........'],
#  ['B57',
#   ' ',
#   '本來',
#   '就是',
#   '啊',
#   '，',
#   '警察',
#   '好像',
#   '很',
#   '好當',
#   '欸',
#   ' ',
#   '啊',
#   '每個',
#   '人',
#   '排隊',
#   '去',
#   '考',
#   '就',
#   '好',
#   '了',
#   '啊',
#   '輪',
#   '的',
#   '到',
#   '他',
#   '嗎',
#   ' ',
#   '一副',
#   '富',
#   '二代',
#   '嘴臉',
#   '的',
#   '紈褲子弟',
#   '講的',
#   '在',
#   '臺北',
#   '能',
#   '買房',
#   '，',
#   '啊',
#   '600',
#   '萬',
#   '，',
#   '哇',
#   '靠',
#   '臺北',
#   '600',
#   '萬',
#   '房子',
#   '，',
#   '三合院',
#   '是',
#   '嗎',
#   '？',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':',
#   '也好',
#   '了',
#   '，',
#   '至少',
#   '有',
#   '神明',
#   '可以',
#   '拜',
#   '還有',
#   '將近',
#   '30',
#   '坪',
#   '呢',
#   '？',
#   ' ',
#   '臺北',
#   '房價',
#   '貴是',
#   '出名',
#   '的',
#   '，',
#   '1400',
#   '萬',
#   '上下',
#   '都',
#   '算',
#   '便宜',
#   '，',
#   '我',
#   '懷疑',
#   '他們',
#   '買',
#   '的',
#   '可能',
#   '是紙',
#   '紮',
#   '屋',
#   '不然',
#   '就是',
#   '淡水',
#   '老街',
#   '附近',
#   ' ',
#   '再',
#   '不是',
#   '就是',
#   '他',
#   '阿祖給',
#   '他',
#   '的',
#   ' ',
#   '也',
#   '算是',
#   '白手起家',
#   '拉',
#   '總',
#   '不能',
#   '睡',
#   '馬路',
#   '啊',
#   ' ',
#   '有',
#   '能力',
#   '的',
#   '人',
#   '臺北',
#   '買房',
#   '都',
#   '買',
#   '將近',
#   '1800',
#   '萬多',
#   '的',
#   '我',
#   '自己',
#   '南部',
#   '房子',
#   '靠近',
#   '捷運',
#   '跟',
#   '文教區',
#   '都',
#   '有',
#   '1500',
#   '，',
#   '他',
#   '那',
#   '北部',
#   '的',
#   '600',
#   '屋來',
#   '炫耀',
#   '自己',
#   '買得起',
#   ' ',
#   '然後',
#   '要',
#   '背',
#   '貸款',
#   '就',
#   '背',
#   '貸款',
#   '那',
#   '是',
#   '你',
#   '的',
#   '命',
#   '，',
#   '不要',
#   '沒本事',
#   '現金',
#   '結清',
#   '就',
#   '在',
#   '哭',
#   '爸',
#   '，',
#   '阿家裡',
#   '不是',
#   '很',
#   '有錢',
#   '，',
#   '怎麼',
#   '不',
#   '叫',
#   '你',
#   '開',
#   '公司',
#   '的',
#   '老爸',
#   '幫',
#   '你',
#   '買紙',
#   '紮',
#   '屋',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':'],
#  ['看不懂',
#   '你',
#   '這篇',
#   '想要',
#   '表達',
#   '什麼',
#   ' ',
#   '所以',
#   '依',
#   '你',
#   '打問號',
#   '的',
#   '地方',
#   '來回',
#   '答',
#   ' ',
#   ' ',
#   'Q',
#   ':',
#   '那',
#   '男生',
#   '會',
#   '不會',
#   '偷看',
#   '女生',
#   '也',
#   '是',
#   '良心',
#   '問題',
#   '吧',
#   '？',
#   ' ',
#   'A',
#   ':',
#   '還會',
#   '有',
#   '法律',
#   '問題',
#   '。',
#   ' ',
#   ' ',
#   'Q',
#   ':',
#   '那',
#   '廁所',
#   '是不是',
#   '就',
#   '都',
#   '改成',
#   '無限',
#   '定',
#   '性別',
#   '廁所',
#   '？',
#   ' ',
#   'A',
#   ':',
#   '這並',
#   '不是',
#   '原本',
#   '設立',
#   '的',
#   '用意',
#   '。',
#   ' ',
#   ' ',
#   'Q',
#   ':',
#   '不然',
#   '男廁',
#   '反而',
#   '對',
#   '男生',
#   '來說',
#   '更',
#   '危險',
#   '？',
#   ' ',
#   'A',
#   ':',
#   '懂得',
#   '尊重',
#   '別人',
#   '，',
#   '懂得',
#   '保護',
#   '自己',
#   '，',
#   '危險',
#   '並不',
#   '限定',
#   '在',
#   '男廁',
#   '發生',
#   '。',
#   ' ',
#   ' ',
#   'Q',
#   ':',
#   '我',
#   '這篇想',
#   '表達',
#   '什麼',
#   '？',
#   ' ',
#   'A',
#   ':',
#   '只是',
#   '想',
#   '寫',
#   '一篇',
#   '湊',
#   '字數',
#   '的',
#   '文章',
#   '來',
#   '罵',
#   '同志',
#   '。'],
#  ['呵呵', ' ', ' ', '假', '的'],
#  ['好',
#   '生動',
#   '的',
#   '描述',
#   ' ',
#   '原來',
#   '台大',
#   '也',
#   '會',
#   '遲到',
#   'XD',
#   ':',
#   'smirking',
#   '_',
#   'face',
#   ':',
#   ':',
#   'smirking',
#   '_',
#   'face',
#   ':',
#   ':',
#   'smirking',
#   '_',
#   'face',
#   ':'],
#  ['B63',
#   ' ',
#   '當然',
#   '可以',
#   '啊',
#   ' ',
#   '我',
#   '捐過',
#   ' ',
#   '前年',
#   '捐',
#   '的',
#   ' ',
#   '今年',
#   '我',
#   '懷孕',
#   '囉',
#   ':',
#   'flexed',
#   '_',
#   'biceps',
#   '_',
#   'light',
#   '_',
#   'skin',
#   '_',
#   'tone',
#   ':'],
#  ['最大',
#   '的',
#   '問題',
#   '是',
#   '你們',
#   '校方',
#   '啊',
#   ' ',
#   '我',
#   '覺得',
#   '如果',
#   '校方',
#   '懂得',
#   '維護',
#   '學生',
#   '權益',
#   ' ',
#   '然後',
#   '不',
#   '同意',
#   '拍攝',
#   ' ',
#   '不',
#   '就',
#   '沒事',
#   '了',
#   ' ',
#   ' ',
#   '不',
#   '懂',
#   '為',
#   '什麼',
#   '要',
#   '把',
#   '矛頭',
#   '指向',
#   '劇組',
#   ' ',
#   '最大',
#   '的',
#   '問題',
#   '是',
#   '你們',
#   '校方',
#   '幹嘛',
#   '同意',
#   '提供',
#   '場地',
#   '啊',
#   ' ',
#   '劇組',
#   '是',
#   '經過',
#   '你們',
#   '學校',
#   '的',
#   '場地',
#   '同意',
#   '所以',
#   '才',
#   '可以',
#   '拍攝',
#   '的',
#   '啊',
#   '…'],
#  ['應援', '鄭鎰勳', ':', 'blue', '_', 'heart', ':'],
#  ['這',
#   '兩家',
#   '公司',
#   '本來',
#   '就是',
#   '一樣',
#   '的',
#   '喔',
#   '～',
#   ' ',
#   '同間',
#   '工廠',
#   '製造',
#   ' ',
#   '母子公司',
#   '～'],
#  ['不會',
#   '回',
#   '宿舍',
#   '看',
#   '喔',
#   ' ',
#   ' ',
#   '沒',
#   '定力',
#   '的',
#   '人',
#   '在',
#   '哪',
#   '都',
#   '沒用',
#   '啦'],
#  ['慣', '老闆', '從裡', '虐到', '外', ' ', '你', '爸', '在', '訓練', '你', '奴性', '呢', '...'],
#  ['法拉利', '停', '樓下', ' ', '不合', '也', '得合'],
#  ['B35',
#   ' ',
#   '你',
#   '要',
#   '不',
#   '要來',
#   '美國',
#   '見識一下',
#   '這邊',
#   '醫護人員',
#   '的',
#   '處理',
#   '態度',
#   '呀',
#   '？',
#   ' ',
#   '掛',
#   '急診',
#   '沒有',
#   '命危',
#   '就是',
#   '等',
#   '，',
#   '等',
#   '個',
#   '五小時',
#   '很',
#   '正常',
#   '。',
#   ' ',
#   '一般',
#   '門診',
#   ' ',
#   '沒事',
#   '就是',
#   '退貨',
#   ' ',
#   '懂嗎',
#   '？',
#   ' ',
#   '回家',
#   '自主',
#   '觀察',
#   '懂嗎',
#   '？',
#   ' ',
#   '當下',
#   '沒事',
#   '留在',
#   '醫院',
#   '是',
#   '會',
#   '有',
#   '幫助',
#   '？',
#   ' ',
#   ' ',
#   '多',
#   '一個',
#   '檢查',
#   '沒事',
#   '的',
#   '人',
#   '先',
#   '佔用',
#   '一個',
#   '可以',
#   '明明',
#   '可以',
#   '給',
#   '其他',
#   '更',
#   '緊急',
#   '的',
#   '病人',
#   '的',
#   '資源',
#   ' ',
#   '那',
#   '一間',
#   '醫院',
#   '還要',
#   '不要',
#   '救人',
#   '呀',
#   '？',
#   ' ',
#   '對',
#   '，',
#   '人命關天',
#   ' ',
#   '問題',
#   ' ',
#   '你家',
#   '人',
#   '的',
#   '命',
#   '是',
#   '命',
#   '別人',
#   '的',
#   '命',
#   '不是',
#   '命',
#   '嗎',
#   '？',
#   ' ',
#   ' ',
#   '搞笑',
#   '耶',
#   ' ',
#   '台灣',
#   '醫療',
#   '就是',
#   '太',
#   '方便',
#   '太',
#   '便宜',
#   '才',
#   '會',
#   '有',
#   '很多',
#   '不',
#   '懂',
#   '珍惜',
#   '不',
#   '懂',
#   '尊重',
#   '專業',
#   '的',
#   '人',
#   '。',
#   ' ',
#   '出國',
#   '看看',
#   '世界',
#   '啦',
#   '，',
#   ' ',
#   '美國',
#   '光叫',
#   '救護車',
#   '就',
#   '可以',
#   '搞垮',
#   '一個',
#   '家庭',
#   '了',
#   '，',
#   '送',
#   '的',
#   '醫院',
#   '還',
#   '不是',
#   '你',
#   '能',
#   '決定',
#   '的',
#   '，',
#   '台灣',
#   '還會',
#   '把',
#   '救護車',
#   '當小黃',
#   '指定',
#   '醫院',
#   '治療',
#   '咧',
#   '。',
#   ' ',
#   ' ',
#   '人體',
#   '本身',
#   '就是',
#   '一個',
#   '很難',
#   '去',
#   '預估',
#   '的',
#   '，',
#   '跟',
#   '你',
#   '講啦',
#   ' ',
#   '目前',
#   '什麼',
#   '百分之幾',
#   '百分之幾',
#   '都',
#   '是',
#   '統計學',
#   '啦',
#   ' ',
#   ' ',
#   '看過',
#   '解剖',
#   '沒',
#   '？',
#   ' ',
#   '培養',
#   '過',
#   '細菌',
#   '沒',
#   '？',
#   ' ',
#   '被過',
#   '上萬',
#   '單字',
#   '跟',
#   '病理',
#   '沒',
#   '？',
#   ' ',
#   '沒有',
#   '就',
#   '不要',
#   '亂戰',
#   '瞭',
#   '不',
#   '？',
#   ' ',
#   '沒',
#   '被',
#   '人',
#   '兇過',
#   '就',
#   '對',
#   '了',
#   '，',
#   '一定',
#   '要',
#   '搞',
#   '的',
#   '每個',
#   '有心',
#   '加入',
#   '醫療',
#   '的',
#   '人',
#   '都',
#   '轉系',
#   '你',
#   '才',
#   '甘心',
#   '嗎',
#   '？',
#   ' ',
#   ' ',
#   '你',
#   '那麼',
#   '厲害',
#   '你',
#   '去',
#   '讀',
#   '呀',
#   '！',
#   ' ',
#   '重',
#   '考上',
#   '醫學院',
#   '後',
#   '在',
#   '來講',
#   '你',
#   '覺得',
#   '慈濟',
#   '醫院',
#   '哪裡',
#   '不',
#   '專業',
#   '。',
#   '（',
#   'sorry',
#   ' ',
#   '慈濟',
#   '的',
#   '同學們',
#   '很棒',
#   '！',
#   '加油',
#   '！',
#   '）'],
#  ['我', '聽過', '一句', '話', ' ', '狗', '改不了', '吃屎'],
#  ['都',
#   '沒人敢',
#   '回',
#   '，',
#   '怕',
#   '被',
#   '我',
#   '嗆',
#   '歐',
#   '╮',
#   '(',
#   '╯',
#   '▽',
#   '╰',
#   ')',
#   '╭'],
#  ['你',
#   '不',
#   '懂',
#   ' ',
#   '我們',
#   '臭酸',
#   '肥宅',
#   '都',
#   '是',
#   '靠',
#   '氣味',
#   '來',
#   '溝通',
#   '的',
#   ':',
#   'face',
#   '_',
#   'blowing',
#   '_',
#   'a',
#   '_',
#   'kiss',
#   ':'],
#  ['同一個', '理髮院', '的', '光頭'],
#  ['雖然',
#   '貴志',
#   '不是',
#   '什麼',
#   '大',
#   '帥哥',
#   ' ',
#   '但是',
#   '他',
#   '是',
#   '個',
#   '超級',
#   '暖',
#   '男',
#   '呀',
#   ':',
#   'red',
#   '_',
#   'heart',
#   ':',
#   '️',
#   ':',
#   'red',
#   '_',
#   'heart',
#   ':',
#   '️',
#   ':',
#   'red',
#   '_',
#   'heart',
#   ':',
#   '️',
#   ' ',
#   '必推',
#   '！',
#   '！',
#   ' ',
#   '*',
#   '夏目',
#   '友人',
#   '帳',
#   '-',
#   '夏目',
#   '貴志'],
#  ['網拍',
#   '三雷',
#   ' ',
#   'LULU',
#   '*',
#   ' ',
#   'MIU',
#   ' ',
#   'STA',
#   '*',
#   ' ',
#   'RAINBOW',
#   ' ',
#   'SHO',
#   '*'],
#  ['B4',
#   '你',
#   '說',
#   '說',
#   ' ',
#   '這是',
#   '你',
#   '第幾次',
#   '使用',
#   '藏頭詩',
#   'get',
#   '失敗',
#   '呢',
#   '~',
#   ' ',
#   'B5',
#   ' ',
#   '超級',
#   '！',
#   '不管',
#   '看',
#   '幾次',
#   '都',
#   '不會',
#   '膩',
#   '~',
#   '每次',
#   '吃飯',
#   '都',
#   '要',
#   '配著',
#   '看',
#   ':',
#   'face',
#   '_',
#   'with',
#   '_',
#   'tears',
#   '_',
#   'of',
#   '_',
#   'joy',
#   ':',
#   ' ',
#   'B7',
#   '握手',
#   '握手',
#   ' ',
#   '我們',
#   '是',
#   '好友'],
#  ['前一陣子', '還有', ' ', 'sent', ' ', 'tree', ' ', 'pay'],
#  ['我',
#   '覺得',
#   '肥宅',
#   '不錯',
#   'R',
#   ' ',
#   '近年來',
#   '肥宅',
#   '似乎',
#   '有',
#   '越來越',
#   '受歡迎',
#   '的',
#   '趨勢'],
#  ['妳', '就是', '這樣', '才', '只能', '做', '服務業', '啦', '幹'],
#  ['Mina',
#   '真的',
#   '是',
#   '很',
#   '一個',
#   '很',
#   '完美',
#   '的',
#   '女神',
#   '啊',
#   '!',
#   '!',
#   '!',
#   '!',
#   ' ',
#   '繼續',
#   '推',
#   'Mina',
#   ':',
#   'beating',
#   '_',
#   'heart',
#   ':',
#   ':',
#   'beating',
#   '_',
#   'heart',
#   ':'],
#  ['B600',
#   ' ',
#   '屁咧',
#   '!',
#   ' ',
#   '八掛',
#   '版',
#   '根本',
#   '仇',
#   '女權',
#   '又',
#   '仇甲好',
#   '嗎',
#   ' ',
#   '仇甲',
#   '的',
#   '大多',
#   '都',
#   '仇',
#   '女權',
#   '啦',
#   ' ',
#   '摸著',
#   '良心',
#   '說',
#   '沒有',
#   '嗎',
#   '？',
#   ' ',
#   ' ',
#   '鄙視',
#   '八掛',
#   '版'],
#  ['練家子',
#   '吧',
#   '。',
#   ' ',
#   '以前',
#   '當兵',
#   '遇過',
#   '，',
#   '的確',
#   '可以',
#   '越級',
#   '挑戰',
#   '。',
#   ' ',
#   '妳',
#   '要',
#   '小心',
#   '了',
#   '......'],
#  ['從沒',
#   '這麼',
#   '想要',
#   '一個',
#   'USB',
#   ' ',
#   '卻',
#   '又',
#   '怕',
#   '打開',
#   '後',
#   '難免',
#   '失落',
#   'XDD',
#   ' '],
#  ['我家',
#   '的',
#   '也',
#   '是',
#   ' ',
#   '做錯',
#   '事情',
#   '被',
#   '罵',
#   '還會',
#   '斜眼',
#   '偷',
#   '瞄討',
#   '救兵',
#   ' ',
#   '超級',
#   '無敵',
#   '撒嬌',
#   '但是',
#   '口水',
#   '超多',
#   ' ',
#   '只要',
#   '我',
#   '牽著',
#   '其他人',
#   '不能',
#   '離',
#   '我',
#   '太近',
#   ' ',
#   '或',
#   '是從',
#   '我',
#   '後面',
#   '靠近',
#   '我',
#   ' ',
#   '會',
#   '低',
#   '吼',
#   '警告',
#   '不會',
#   '主動攻擊',
#   ' ',
#   '是',
#   '一種',
#   '很',
#   '忠心',
#   '護主',
#   '的',
#   '狗狗',
#   ' ',
#   '我家',
#   '的',
#   '大概',
#   '80',
#   '公斤',
#   ' ',
#   '回家',
#   '撲上來',
#   '連',
#   '摩托車',
#   '都',
#   '會',
#   '被',
#   '掐',
#   '掐',
#   '倒',
#   ' ',
#   '但是',
#   '前一陣子',
#   '過世',
#   '了',
#   ' ',
#   '還',
#   '不敢',
#   '去',
#   '翻',
#   '照片',
#   '...',
#   ' ',
#   ' ',
#   'B32',
#   ' ',
#   '獒',
#   '展',
#   '大家',
#   '都',
#   '可以',
#   '去',
#   '參觀',
#   ' ',
#   '現場',
#   '也',
#   '會',
#   '有',
#   '很多',
#   '人帶',
#   '親人',
#   '的',
#   '大',
#   '獒',
#   ' ',
#   '或是',
#   '獒',
#   '寶寶',
#   '去',
#   '玩耍',
#   ' ',
#   '你',
#   '也',
#   '可以',
#   '徵求',
#   '主人',
#   '同意',
#   '跟',
#   '他們',
#   '玩',
#   '哦',
#   '！'],
#  ['沒有', '洞', '就', '沒有', '驚天動地', '唷', '～'],
#  ['再',
#   '找',
#   '一個',
#   '工作',
#   '順便',
#   '檢舉',
#   '他',
#   '吧',
#   ' ',
#   '最低工資',
#   '現在',
#   '是',
#   '133',
#   '耶'],
#  ['好', '垃圾'],
#  ['我們', '浣熊', '和', '小', '真榮', '啊', 'QQQQ'],
#  ['好',
#   '啦',
#   '我們',
#   '頂',
#   '大生',
#   '上課',
#   '又',
#   '廢',
#   '又',
#   '沒有',
#   '思考',
#   '能力',
#   '態度',
#   '還很差',
#   '以後',
#   '沒人要',
#   ' ',
#   '有沒有',
#   '要',
#   '揪',
#   '團去',
#   '旁邊',
#   '哭',
#   '的',
#   'QAQ'],
#  ['B77',
#   ' ',
#   '鵝',
#   ' ',
#   '你',
#   '好像',
#   '在',
#   '形容',
#   '你',
#   '自己',
#   '呢',
#   ' ',
#   '我們',
#   '頂',
#   '大戰',
#   '戰校',
#   '真的',
#   '只是',
#   '促進',
#   '血液循環',
#   '而已',
#   '，',
#   '畢業',
#   '真',
#   '沒',
#   '聽過',
#   '幾個',
#   '再',
#   '找',
#   '工作',
#   '的',
#   '，',
#   '進竹科',
#   '大概',
#   '跟',
#   '你們',
#   '時薪',
#   '打工',
#   '的',
#   '差不多',
#   '多'],
#  ['沒事', '沒事', ' ', '繼續', '檢舉', ' ', '越多人', '檢舉', '越', '容易', '成功'],
#  ['同學',
#   ':',
#   ' ',
#   '您好',
#   '，',
#   '我',
#   '是',
#   '中央大學',
#   '金筆',
#   '獎小編',
#   '，',
#   '我',
#   '覺得',
#   '您',
#   '的',
#   '文章',
#   '富含',
#   '感情',
#   '，',
#   '將',
#   '同學',
#   '和',
#   '朋友',
#   '之間',
#   '愛恨',
#   '情仇',
#   '寫',
#   '的',
#   '如此',
#   '生動',
#   '，',
#   '短短的',
#   '幾句',
#   '卻',
#   '打動',
#   '無數',
#   '人',
#   '內心',
#   '的',
#   '悸動',
#   '，',
#   '歡迎您',
#   '的',
#   '投稿',
#   '。',
#   ' ',
#   '金筆',
#   '獎',
#   '全體同仁',
#   '祝您',
#   ' ',
#   '生體',
#   '健康',
#   ' ',
#   '萬事如意'],
#  ['我們',
#   '並',
#   '不會',
#   '在意',
#   '這個',
#   '舉動',
#   '，',
#   '然後',
#   '交給',
#   '律師',
#   '處理',
#   '，',
#   'ㄏ',
#   '?',
#   '有事嗎',
#   '？',
#   '假鬼',
#   '假怪'],
#  ['B174',
#   '這次',
#   '的',
#   '事件',
#   '跟',
#   '異性戀',
#   '是否',
#   '破壞',
#   '別人',
#   '家庭',
#   '無關',
#   '唷',
#   '！',
#   ' ',
#   '這次',
#   '的',
#   '事件',
#   '是',
#   '同性戀',
#   '破壞',
#   '異性戀',
#   '的',
#   '家庭',
#   '，',
#   '見',
#   '不得',
#   '異性戀',
#   '家庭',
#   '好',
#   '，',
#   '所以',
#   '同志',
#   '心生',
#   '歹念',
#   '，',
#   '破壞',
#   '起',
#   '異性戀',
#   '的',
#   '家庭',
#   ' ',
#   '實在',
#   '令人髮指',
#   ' ',
#   ' ',
#   'B174',
#   '我',
#   '是',
#   '在',
#   '哪裡',
#   '主張',
#   '「',
#   '異性戀',
#   '不會',
#   '破壞',
#   '別人',
#   '家庭',
#   '」',
#   '的',
#   '論述',
#   '了',
#   '，',
#   '你',
#   '要',
#   '挺',
#   '同',
#   '我',
#   '也',
#   '尊重',
#   '，',
#   '但是',
#   '挺同',
#   '挺',
#   '到',
#   '滑坡',
#   '去',
#   '鬼扯',
#   '什麼',
#   '異性戀',
#   '不會',
#   '破壞',
#   '別人',
#   '家庭',
#   '，',
#   '實在',
#   '是',
#   '讓',
#   '你',
#   '的',
#   '挺',
#   '同',
#   '夥伴',
#   '蒙羞',
#   '唷',
#   '！'],
#  ['B79',
#   ' ',
#   '就是',
#   '智商',
#   '低',
#   '才學',
#   '簡體字',
#   ' ',
#   '非',
#   '支那',
#   '人學',
#   '簡體字',
#   '也',
#   '只是',
#   '為',
#   '了',
#   '賺',
#   '你們',
#   '的',
#   '錢',
#   ' ',
#   '道理',
#   '跟',
#   '全世界',
#   '都',
#   '學',
#   '美式英語',
#   '一樣',
#   ' ',
#   '多讀',
#   '點書',
#   '再來',
#   '戰',
#   ' ',
#   '智障',
#   ' ',
#   '智障',
#   '才',
#   '不',
#   '知道',
#   '英式',
#   '英語',
#   '跟',
#   '正體',
#   '中文',
#   '的',
#   '文化性'],
#  ['因為',
#   '一時',
#   '情緒',
#   '傷害',
#   '別人',
#   '一輩子',
#   ' ',
#   '還',
#   '覺得',
#   '理所當然',
#   ' ',
#   '之後',
#   '賠',
#   '了',
#   '20',
#   '萬',
#   ' ',
#   '還',
#   '覺得',
#   '自己',
#   '唯一',
#   '的',
#   '錯',
#   '在',
#   '沒有',
#   '全身而退',
#   '？'],
#  ['唉',
#   ' ',
#   '曉秋',
#   '自己',
#   '不改',
#   '她',
#   '那個',
#   '個性',
#   ' ',
#   '就',
#   '不是',
#   '可憐',
#   '了',
#   ' ',
#   '是',
#   '智障',
#   '吧',
#   ' ',
#   '由',
#   '其',
#   '是',
#   '看到',
#   '她',
#   '在',
#   '幫',
#   '正凱媽',
#   '講話',
#   '那段',
#   ' ',
#   '整個',
#   '傻眼'],
#  ['B38',
#   ' ',
#   '我',
#   '不是',
#   '為',
#   '了',
#   '要',
#   '不要',
#   '被',
#   '講話',
#   '而',
#   '選擇',
#   '溫柔',
#   '與否',
#   ' ',
#   '是',
#   '溫柔',
#   '的',
#   '人',
#   '值得',
#   '被',
#   '溫柔',
#   '對待',
#   ' ',
#   '某些',
#   '智障',
#   '粉絲',
#   '還是',
#   '算了吧',
#   ' ',
#   ' ',
#   'B33',
#   ' ',
#   '難得',
#   '溫柔',
#   '的',
#   '回應',
#   '一下',
#   ' ',
#   '那',
#   '你',
#   '不',
#   '喜歡',
#   '的',
#   '留言',
#   '可以',
#   '不要',
#   '看',
#   ' ',
#   ' ',
#   'B36',
#   ' ',
#   '你',
#   '是不是',
#   '真的',
#   '...',
#   ' ',
#   '在場',
#   '說',
#   '了',
#   '誰',
#   '是',
#   '龍蝦',
#   '？',
#   ' ',
#   '對',
#   '啊',
#   '人',
#   '都',
#   '有',
#   '自主權',
#   '，',
#   '也',
#   '有',
#   '發言權',
#   ' ',
#   '所以',
#   '留言',
#   '你',
#   '不',
#   '喜',
#   '勿',
#   '看',
#   ' ',
#   '給',
#   '你們',
#   '建議',
#   '也',
#   '不要',
#   '還要',
#   '被',
#   '罵',
#   ' ',
#   '我',
#   '真的',
#   '是',
#   '衰小',
#   '，',
#   '你',
#   '就是',
#   '那群',
#   '不',
#   '值得',
#   '被',
#   '溫柔',
#   '對待',
#   '的',
#   '粉絲',
#   ' ',
#   '繼續',
#   '招黑',
#   '，',
#   '沒差',
#   '啦'],
#  ['別',
#   '這樣',
#   '，',
#   '不然',
#   '男孩',
#   '版',
#   '又',
#   '要',
#   '玻璃心',
#   '了',
#   '(',
#   '●',
#   '°',
#   'u',
#   '°',
#   '●',
#   ')',
#   '\u200b',
#   ' ',
#   '」'],
#  ['價值',
#   '與否',
#   '不是',
#   '由系',
#   '決定',
#   ' ',
#   '而是',
#   '靠',
#   '自己',
#   '努力',
#   ' ',
#   '再',
#   '好',
#   '的',
#   '系',
#   '都',
#   '有',
#   '敗筆',
#   ' ',
#   '例如',
#   '發',
#   '這篇文',
#   '打算',
#   '引戰',
#   ' ',
#   '卻',
#   '又',
#   '不秀系',
#   '別的',
#   '你'],
#  ['Light',
#   ':',
#   'sparkles',
#   ':',
#   '來',
#   '報到',
#   '！',
#   ' ',
#   '以前',
#   '最',
#   '喜歡',
#   '看',
#   '厲旭',
#   '跟',
#   '東',
#   '雲',
#   '主持',
#   'Chart',
#   ' ',
#   'Show',
#   ' ',
#   '打給',
#   '各家',
#   'Idol',
#   '套話',
#   ' ',
#   '亂聊',
#   '亂猜',
#   '自己',
#   '上榜',
#   '原因',
#   ' ',
#   '在',
#   '這邊',
#   '要祝孫',
#   '男神',
#   '生日快樂',
#   ' ',
#   '동',
#   '운',
#   ' ',
#   '생',
#   '일',
#   ' ',
#   '축',
#   '하',
#   '합',
#   '니',
#   '다',
#   ' ',
#   ':',
#   'birthday',
#   '_',
#   'cake',
#   ':',
#   ':',
#   'birthday',
#   '_',
#   'cake',
#   ':',
#   ':',
#   'birthday',
#   '_',
#   'cake',
#   ':',
#   ':',
#   'birthday',
#   '_',
#   'cake',
#   ':',
#   ':',
#   'birthday',
#   '_',
#   'cake',
#   ':'],
#  ...]

# %%
model = Word2Vec(words, size=200, min_count=1, iter=10)
model.save('word2vec.model')

# %%
print(model)
# Out:
# Word2Vec(vocab=127388, size=200, alpha=0.025)
